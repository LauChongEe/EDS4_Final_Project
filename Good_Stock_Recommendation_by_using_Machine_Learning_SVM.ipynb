# %% [markdown]
# ## 2. Support Vector Machine (SVM)

# %%
#import library
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import datetime
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

#analysis target
how_much_better = 10
invest_unit_per_stock = 1
current_key_stats = datetime.datetime(2018, 2, 5, 0, 0)

#analysis features
Analysis_Features = [
                     'Market Cap',
                     'Enterprise Value',
                     'Trailing P/E',
                     'Forward P/E',
                     'PEG Ratio',
                     'Price/Sales',
                     'Enterprise Value/Revenue',
                     'Profit Margin',
                     'Operating Margin', 
                     'Return on Equity',
                     'Revenue',
                     'Revenue Per Share',                         
                     'Net Income Avl to Common',
                     'Diluted EPS',
                     'Total Cash',
                     'Total Cash Per Share',
                     'Total Debt',
                     'Book Value Per Share',
                     'Operating Cash Flow',
                     'Beta',
                     '% Held by Insiders',
                     '% Held by Institutions',
                     'Shares Short', 
                     'Short Ratio'
                    ]

# %% [markdown]
# ### Stock ranking

# %%
#define function to rank stock based on differences between stock price changes & S&P 500 index changes
def Rank_Stock(row):  
    if row['Stock Price vs S&P 500 Index'] > how_much_better:
        #print(row['Ticker'], row['Stock Price vs S&P 500 Index'])
        return 1
    else:
        return 0
    
#define function to rank stock based on differences compare to its previous price
def Rank_Stock_By_Historical(row):
    if row["Stock Price Change"] > how_much_better:
        #print(row['Ticker'], row["Stock Price Change"])
        return 1
    else:
        return 0

# %% [markdown]
# ### Data load

# %%
#define function to load historical data
def Load_Historical_Data():
    historical_data_path = os.path.join(os.path.join(os.getcwd(), 'Data'), "Historical.csv")
    df = pd.read_csv(historical_data_path, sep=',')#.iloc[:,1:]
    return df

#define function to load forward data
def Load_Forward_Data():
    forward_data_path = os.path.join(os.path.join(os.getcwd(), 'Data'), "Forward.csv")
    df = pd.read_csv(forward_data_path, sep=',')#.iloc[:,1:]
    return df

# %% [markdown]
# ### Load Yahoo Finance stock price

# %%
#using 3rd party code from https://github.com/c0redumb/yahoo_quote_download to download stock price from Yahoo Finance
import yahoo_quote_download as yqd
from datetime import datetime, timedelta
import pandas as pd

def load_quote(ticker, startDate, endDate, search_method='F', count=0):
    count+=1
#     if startDate.weekday() == 5:
#         startDate = startDate + timedelta(days=2)
#     elif startDate.weekday() == 6:
#         startDate = startDate + timedelta(days=1)
        
#     if endDate.weekday() == 5:
#         endDate = endDate + timedelta(days=2)
#     elif endDate.weekday() == 6:
#         endDate = endDate + timedelta(days=1)
        
    start = startDate.strftime('%Y%m%d')
    end = endDate.strftime('%Y%m%d')    
    data = yqd.load_yahoo_quote(ticker, start, end)   
#     print('===', ticker, start, end, search_method, count, data,'===')
    df = pd.DataFrame([sub.split(",") for sub in data if len(sub.split(",")[0])>0 and sub.split(",")[0] != 'Date'], columns=['Date','Open','High','Low','Close','Adj Close','Volume'])    
      
    if len(df) == 0 and count < 10:
        value = None
        if search_method=='F':
            startDate = startDate + timedelta(days=1)
            endDate = endDate + timedelta(days=1)
        else:
            startDate = startDate - timedelta(days=1)
            endDate = endDate - timedelta(days=1)
            
        return load_quote(ticker, startDate, endDate, search_method, count)
    else:        
        value = df.iloc[0]['Adj Close'] if len(df) > 0 else None
    return value#df

# %% [markdown]
# ### Check for NaN value in data

# %%
def Check_Null_Data(df):
    #check for NaN data   
    #as there're a lot of N/A data, cautious approach will be implemented for stock analysis to follow rules of:
    #1) Avoid loss 
    #2) Do not forget rule#1
    #All N/A data found in key features used for analysis will be removed.
    return df.isnull().sum()

# %% [markdown]
# ### Data cleaning and null value handling

# %%
#define function to preprocess data
def Historical_Data_Preprocessing_All_Industry(df, ranking=0):     
    #df = Load_Historical_Data()
    
    #drop row with any NA value based on Analysis Features + Stock Price 
    df = df.dropna(subset=['Stock Price']+Analysis_Features, how='any').reset_index().drop(['index'], axis=1)  
        
    #features data set
    X = df[Analysis_Features]  
    
    #label data set    
    if ranking==0:
        df['Ranking'] = df.apply(Rank_Stock, axis=1)
    else:
        df['Ranking'] = df.apply(Rank_Stock_By_Historical, axis=1)
    y = df['Ranking']
    
    return X,y

#define function to preprocess data
def Forward_Data_Preprocessing_All_Industry(df): 
    #df = Load_Forward_Data()
    
    #drop row with any NA value based on Analysis Features + Stock Price 
    df = df.dropna(subset=['Ticker','Security','GICS Sector','GICS Sub Industry']+Analysis_Features, how='any').reset_index().drop(['index'], axis=1)
       
    #features data set
    X = df[Analysis_Features]
    
    #Listed company data set 
    z = df[['Ticker','Security','GICS Sector','GICS Sub Industry']]    
        
    return X,z

# %% [markdown]
# ### Train and Test Dataset Split

# %%
from sklearn.model_selection import train_test_split

def Train_Test_Split(X, y):
    #For the sake of testing our classifier output, we will split the data into a training and testing set
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
    #X_columns = list(X_train)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### Feature Scaling and Normalization

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

def Standard_Scale(X_train, X_test, X_ver):
    scaler = StandardScaler()
    #standard scale transform
    X_train_std_scale = scaler.fit_transform(X_train)
    X_test_std_scale = scaler.transform(X_test)
    X_ver_std_scale = scaler.transform(X_ver)
    return X_train_std_scale, X_test_std_scale, X_ver_std_scale

def MinMax_Scale(X_train, X_test, X_ver):
    scaler = MinMaxScaler()
    #MinMax scale transform
    X_train_mm_scale = scaler.fit_transform(X_train)
    X_test_mm_scale = scaler.transform(X_test)
    X_ver_mm_scale = scaler.transform(X_ver)
    return X_train_mm_scale, X_test_mm_scale, X_ver_mm_scale

# %% [markdown]
# ### PCA - choosing number of components

# %%
from sklearn.decomposition import PCA

def PCA_Component_Analysis(X_train):
    pca = PCA()
    X_train_PCA = pca.fit_transform(X_train) #fit_transform X_train

    plt.plot(np.cumsum(pca.explained_variance_ratio_))
    plt.xlabel('number of components')
    plt.ylabel('cumulative explained variance');
    plt.show();
    
def PCA_Component_Selection(n_components, X_train, X_test, X_ver):
    #choose 15 components for PCA to reduce features
    pca = PCA(n_components=n_components)

    X_train_PCA = pca.fit_transform(X_train)
    X_test_PCA = pca.transform(X_test)
    X_ver_PCA = pca.transform(X_ver)
    return X_train_PCA, X_test_PCA, X_ver_PCA

# %% [markdown]
# ### Imbalance dataset handling

# %%
from imblearn.under_sampling import RandomUnderSampler

def Down_Sample_Dataset(X, y):  
    rus = RandomUnderSampler(return_indices=True, random_state=42)
    X_undersampling, y_undersampling, idx_resampled = rus.fit_sample(X, y)
    print('Y before down-sampling:', np.unique(y,return_counts=True))
    print('Y after down-sampling:', np.unique(y_undersampling,return_counts=True))
    return X_undersampling, y_undersampling

# %% [markdown]
# ### Model Execution with SVM

# %%
def SVM_Run(X_train, y_train, X_test, y_test, X_ver, calc_return=True, penalized=False):
    #SVC 
    from sklearn.svm import SVC
    if penalized == True:
        model = SVC(class_weight='balanced', probability=True).fit(X_train, y_train)
    else:
        model = SVC(probability=True).fit(X_train, y_train)

    # SVC Default accuracy 
    print('SVC Default (accuracy) Train Dataset', model.score(X_train, y_train))
    print('SVC Default (accuracy) Test Dataset', model.score(X_test, y_test))
    print()

    # SVC Default metric report
    from sklearn import metrics
    y_pred = model.predict(X_test)
    print('SVC Default Metric Report:')
    print(metrics.classification_report(y_pred, y_test))

    # SVC Default Confusion Matrix
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    print('SVC Default Confusion Matrix:')
    mat = confusion_matrix(y_test, y_pred)
    sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
    plt.xlabel('true label')
    plt.ylabel('predicted label')
    plt.show();

    # Calculate AUROC
    from sklearn.metrics import roc_auc_score
    y_prob = model.predict_proba(X_test)
    y_prob = [p[1] for p in y_prob]

    from sklearn.metrics import roc_curve, auc
    fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label=1)
    auc_result = auc(fpr, tpr)
    print('ROC Curve')
    print('AUROC Score:',roc_auc_score(y_test, y_prob))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='area = {0:0.2f}'.format(auc_result))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()

    #test with latest stock key statistic
    import datetime
    print('Predict using latest Key Statistic @ {0}'.format(current_key_stats.strftime('%Y-%m-%d')))    
    y_pred = model.predict(X_ver)

    counter=0
    invest_list = []
    initial_price = []
    current_price = []
    investment_cost = []
    investment_return = []
    profit_loss = []
    for t in y_pred:   
         if t == 1:                
            invest_list.append(z.iloc[counter]['Security'])            
            if calc_return == True:        
                ini_price = load_quote(z.iloc[counter]['Ticker'],current_key_stats,current_key_stats, search_method='F')        
                cur_price = load_quote(z.iloc[counter]['Ticker'],datetime.date.today()-timedelta(days=1),datetime.date.today()-timedelta(days=1), search_method='B')  
                if ini_price != None:
                    ini_price = round(float(ini_price),2)
                    inv_cost = round(float(ini_price)*invest_unit_per_stock,2)
                else:
                    inv_cost = None
                if cur_price != None:
                    cur_price = round(float(cur_price),2)
                    inv_return = round(float(cur_price)*invest_unit_per_stock,2)
                else:
                    inv_return = None
                if inv_cost != None and inv_return != None:
                    pl = round(inv_return-inv_cost,2)
                else:
                    pl = None
                
                initial_price.append(ini_price)
                current_price.append(cur_price)
                investment_cost.append(inv_cost)
                investment_return.append(inv_return)
                profit_loss.append(pl)
         counter+=1
    
    print()
    if calc_return == True:
        df_rcmd = pd.DataFrame({
                                'Company':invest_list,
                                'Initial Price':initial_price,
                                'Current Price':current_price,
                                'Investment Cost':investment_cost,
                                'Investment Return':investment_return,
                                'Profit/Loss':profit_loss
                                }
                                , columns=['Company',
                                           'Initial Price',
                                           'Current Price',
                                           'Investment Cost',
                                           'Investment Return',
                                           'Profit/Loss'])
        print('Recommended companies for investment and total return as below:')
        print('Total earning from [{0}] till [{1}] is [${2}]'.format(current_key_stats.strftime('%Y-%m-%d'), datetime.datetime.today().strftime('%Y-%m-%d'), round(df_rcmd['Profit/Loss'].sum(),2)))
        print('Total investment cost so far is [${0}]'.format(round(df_rcmd['Investment Cost'].sum(),2)))
        print('Total investment return so far is [${0}]'.format(round(df_rcmd['Investment Return'].sum(),2)))
        print('Total investment return % gain so far is [{0}%]'.format(round(df_rcmd['Profit/Loss'].sum(),2)/round(df_rcmd['Investment Cost'].sum(),2)))
        print()
        df_top10 = df_rcmd.nlargest(10, 'Profit/Loss').reset_index().drop(['index'],axis=1)
        print('Top 10 companies by investment profit:')
        print('Top 10 Total investment cost so far is [${0}]'.format(round(df_top10['Investment Cost'].sum(),2)))
        print('Top 10 Total investment return so far is [${0}]'.format(round(df_top10['Investment Return'].sum(),2)))
        print('Top 10 Total investment return % gain so far is [{0}%]'.format(round(df_top10['Profit/Loss'].sum(),2)/round(df_top10['Investment Cost'].sum(),2)))        
        print(df_top10)
    else:
        print('Recommended companies for investment as below:')
        df_rcmd = pd.DataFrame(invest_list, columns=['Company'])   
    
    return df_rcmd

# %% [markdown]
# ### Model Execution with GridSearch for Penalized-SVM

# %%
def GridSearch_Penalized_SVM_Run(X_train, y_train, X_test, y_test, X_ver, calc_return=True):
    from sklearn.model_selection import GridSearchCV
    from sklearn.svm import SVC
    model = SVC(class_weight='balanced', probability=True)

    # Create regularization kernel space
    kernel = ['linear', 'rbf']

    # Create regularization hyperparameter space
    C = [1, 5, 10, 50]
    
    # Create regularization hyperparameter space
    gamma = [0.0001, 0.0005, 0.001, 0.005]   

    # Create hyperparameter options
    hyperparameters = dict(kernel=kernel, C=C, gamma=gamma)

    # Create grid search using 5-fold cross validation
    clf = GridSearchCV(model, hyperparameters, cv=5, verbose=0)

    # Fit grid search
    best_model = clf.fit(X_train, y_train)

    # View best hyperparameters
    print('GridSearch SVC Best Kernel:', best_model.best_estimator_.get_params()['kernel'])
    print('GridSearch SVC Best C:', best_model.best_estimator_.get_params()['C'])
    print('GridSearch SVC Best gamma:', best_model.best_estimator_.get_params()['gamma'])

    # SVC Default accuracy 
    print('GridSearch SVC Default (accuracy) Train Dataset', best_model.score(X_train, y_train))
    print('GridSearch SVC Default (accuracy) Test Dataset', best_model.score(X_test, y_test))
    print()

    # SVC Default metric report
    from sklearn import metrics
    y_pred = best_model.predict(X_test)
    print('GridSearch SVC Default Metric Report:')
    print(metrics.classification_report(y_pred, y_test))

    # SVC Default Confusion Matrix
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    print('GridSearch SVC Default Confusion Matrix:')
    mat = confusion_matrix(y_test, y_pred)
    sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
    plt.xlabel('true label')
    plt.ylabel('predicted label')
    plt.show();

    # Calculate AUROC
    from sklearn.metrics import roc_auc_score   
    y_prob = best_model.predict_proba(X_test)
    y_prob = [p[1] for p in y_prob]

    from sklearn.metrics import roc_curve, auc
    fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label=1)
    auc_result = auc(fpr, tpr)
    print('GridSearch SVC ROC Curve')
    print('AUROC Score:',roc_auc_score(y_test, y_prob))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='area = {0:0.2f}'.format(auc_result))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()

    #test with latest stock key statistic
    import datetime
    print('Predict using latest Key Statistic @ {0}'.format(current_key_stats.strftime('%Y-%m-%d')))   
    y_pred = best_model.predict(X_ver)

    counter=0
    invest_list = []
    initial_price = []
    current_price = []
    investment_cost = []
    investment_return = []
    profit_loss = []
    for t in y_pred:   
         if t == 1:                
            invest_list.append(z.iloc[counter]['Security'])            
            if calc_return == True:        
                ini_price = load_quote(z.iloc[counter]['Ticker'],current_key_stats,current_key_stats,search_method='F')        
                cur_price = load_quote(z.iloc[counter]['Ticker'],datetime.date.today()-timedelta(days=1),datetime.date.today()-timedelta(days=1),search_method='B')  
                if ini_price != None:
                    ini_price = round(float(ini_price),2)
                    inv_cost = round(float(ini_price)*invest_unit_per_stock,2)
                else:
                    inv_cost = None
                if cur_price != None:
                    cur_price = round(float(cur_price),2)
                    inv_return = round(float(cur_price)*invest_unit_per_stock,2)
                else:
                    inv_return = None
                if inv_cost != None and inv_return != None:
                    pl = round(inv_return-inv_cost,2)
                else:
                    pl = None
                
                initial_price.append(ini_price)
                current_price.append(cur_price)
                investment_cost.append(inv_cost)
                investment_return.append(inv_return)
                profit_loss.append(pl)
         counter+=1
    
    print()
    if calc_return == True:
        df_rcmd = pd.DataFrame({
                                'Company':invest_list,
                                'Initial Price':initial_price,
                                'Current Price':current_price,
                                'Investment Cost':investment_cost,
                                'Investment Return':investment_return,
                                'Profit/Loss':profit_loss
                                }
                                , columns=['Company',
                                           'Initial Price',
                                           'Current Price',
                                           'Investment Cost',
                                           'Investment Return',
                                           'Profit/Loss'])
        print('Recommended companies for investment and total return as below:')
        print('Total earning from [{0}] till [{1}] is [${2}]'.format(current_key_stats.strftime('%Y-%m-%d'), datetime.datetime.today().strftime('%Y-%m-%d'), round(df_rcmd['Profit/Loss'].sum(),2)))
        print('Total investment cost so far is [${0}]'.format(round(df_rcmd['Investment Cost'].sum(),2)))
        print('Total investment return so far is [${0}]'.format(round(df_rcmd['Investment Return'].sum(),2)))
        print('Total investment return % gain so far is [{0}%]'.format(round(df_rcmd['Profit/Loss'].sum(),2)/round(df_rcmd['Investment Cost'].sum(),2)))
        print()
        df_top10 = df_rcmd.nlargest(10, 'Profit/Loss').reset_index().drop(['index'],axis=1)
        print('Top 10 companies by investment profit:')
        print('Top 10 Total investment cost so far is [${0}]'.format(round(df_top10['Investment Cost'].sum(),2)))
        print('Top 10 Total investment return so far is [${0}]'.format(round(df_top10['Investment Return'].sum(),2)))
        print('Top 10 Total investment return % gain so far is [{0}%]'.format(round(df_top10['Profit/Loss'].sum(),2)/round(df_top10['Investment Cost'].sum(),2)))        
        print(df_top10)
    else:
        print('Recommended companies for investment as below:')
        df_rcmd = pd.DataFrame(invest_list, columns=['Company'])   
    
    return df_rcmd

# %% [markdown]
# ### Data preparation, preprocessing

# %%
#load historical & current Key Financial Statistic data
df_historical = Load_Historical_Data()
df_forward = Load_Forward_Data()

#check if there's any NaN data in historical & current data
historical_null_val = Check_Null_Data(df_historical)
print('Null value in columns for Historical Data:')
print(historical_null_val)
print()
print('Null value in columns for Forward Data:')
forward_null_val = Check_Null_Data(df_forward)
print(forward_null_val)
print()
# Out:
# Null value in columns for Historical Data:
# Ranking                              0
# Date                                 0
# Unix_Time                            0
# Ticker                               0
# Security                             0
# GICS Sector                          0
# GICS Sub Industry                    0
# Stock Price                        145
# Stock Price Change                   0
# S&P 500 Index                        0
# S&P 500 Index Change                 0
# Stock Price vs S&P 500 Index         0
# Market Cap                          12
# Enterprise Value                    38
# Trailing P/E                       346
# Forward P/E                         84
# PEG Ratio                          162
# Price/Sales                         14
# Price/Book                          69
# Enterprise Value/Revenue            39
# Enterprise Value/EBITDA            440
# Profit Margin                        3
# Operating Margin                    68
# Return on Assets                    87
# Return on Equity                    78
# Revenue                              2
# Revenue Per Share                    1
# Gross Profit                        96
# EBITDA                             367
# Net Income Avl to Common             0
# Diluted EPS                         19
# Total Cash                          30
# Total Cash Per Share                17
# Total Debt                          16
# Total Debt/Equity                  777
# Current Ratio                      489
# Book Value Per Share                 0
# Operating Cash Flow                283
# Levered Free Cash Flow             545
# Beta                               202
# % Held by Insiders                  37
# % Held by Institutions              29
# Shares Short                         0
# Short Ratio                          3
# Short % of Float                   227
# Shares Short.1                       0
# Trailing Annual Dividend Rate     1473
# Trailing Annual Dividend Yield    1063
# dtype: int64
#
# Null value in columns for Forward Data:
# Ranking                           365
# Date                              365
# Unix_Time                         365
# Ticker                              0
# Security                            0
# GICS Sector                         0
# GICS Sub Industry                   0
# Stock Price                       365
# Stock Price Change                365
# S&P 500 Index                     365
# S&P 500 Index Change              365
# Stock Price vs S&P 500 Index      365
# Market Cap                          0
# Enterprise Value                    0
# Trailing P/E                       38
# Forward P/E                         1
# PEG Ratio                           0
# Price/Sales                         0
# Price/Book                         12
# Enterprise Value/Revenue            0
# Enterprise Value/EBITDA             5
# Profit Margin                       0
# Operating Margin                    0
# Return on Assets                    8
# Return on Equity                    8
# Revenue                             0
# Revenue Per Share                   0
# Gross Profit                        2
# EBITDA                              5
# Net Income Avl to Common            0
# Diluted EPS                         0
# Total Cash                          1
# Total Cash Per Share                1
# Total Debt                          7
# Total Debt/Equity                  17
# Current Ratio                       9
# Book Value Per Share                0
# Operating Cash Flow                23
# Levered Free Cash Flow             30
# Beta                                1
# % Held by Insiders                  2
# % Held by Institutions              2
# Shares Short                       30
# Short Ratio                        15
# Short % of Float                    0
# Shares Short.1                     30
# Trailing Annual Dividend Rate      47
# Trailing Annual Dividend Yield     31
# dtype: int64

# %% [markdown]
# ### Stock Analysis using SVM + Standard Scale + Down-Sampling Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_std_scale, X_test_std_scale, X_ver_std_scale = Standard_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_std_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
X_train_std_scale_reduce, y_train_reduce = Down_Sample_Dataset(X_train_std_scale, y_train)

#model execution with SVM
df_result = SVM_Run(X_train_std_scale_reduce, y_train_reduce, X_test_std_scale, y_test, X_ver_std_scale, calc_return=True)
df_result.to_csv('SVM_Std_Scale_Down_Sampling.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# Y before down-sampling: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y after down-sampling: (array([0, 1], dtype=int64), array([461, 461], dtype=int64))
# SVC Default (accuracy) Train Dataset 0.695227765727
# SVC Default (accuracy) Test Dataset 0.505677517033
#
# SVC Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.48      0.92      0.63       605
#           1       0.70      0.15      0.25       716
#
# avg / total       0.60      0.51      0.42      1321
#
# SVC Default Confusion Matrix:
# ROC Curve
# AUROC Score: 0.650993194268
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$681.96]
# Total investment cost so far is [$15330.88]
# Total investment return so far is [$16012.84]
# Total investment return % gain so far is [0.04448276941701977%]
#
# Top 10 companies by investment profit:
# Top 10 Total investment cost so far is [$2047.79]
# Top 10 Total investment return so far is [$2349.38]
# Top 10 Total investment return % gain so far is [0.14727584371444336%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6         Western Digital          81.45         102.91            81.45
# 7        Sherwin-Williams         392.38         413.77           392.38
# 8             Intuit Inc.         157.65         177.68           157.65
# 9        KLA-Tencor Corp.         100.63         120.48           100.63
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             102.91        21.46
# 7             413.77        21.39
# 8             177.68        20.03
# 9             120.48        19.85
#                           Company  Initial Price  Current Price  \
# 0             Activision Blizzard          67.98          75.93
# 1               Adobe Systems Inc         190.27         219.76
# 2                       Aetna Inc         180.95         177.44
# 3    Air Products & Chemicals Inc         156.33         170.93
# 4         Akamai Technologies Inc          62.81          73.30
# 5         Alexion Pharmaceuticals         112.72         121.08
# 6           American Tower Corp A         142.04         146.25
# 7                   Amphenol Corp          88.41          92.51
# 8            Analog Devices, Inc.          84.96          94.66
# 9                         Aon plc         140.34         145.96
# 10             Apache Corporation          40.93          35.46
# 11      Automatic Data Processing         113.45         117.39
# 12    AvalonBay Communities, Inc.         159.02         161.52
# 13            Avery Dennison Corp         113.36         115.91
# 14                      Ball Corp          36.42          41.62
# 15      Baxter International Inc.          65.37          68.09
# 16              Best Buy Co. Inc.          68.02          71.52
# 17                    Biogen Inc.         328.31         283.24
# 18                     BorgWarner          52.17          50.83
# 19              Boston Scientific          26.40          28.43
# 20       C. H. Robinson Worldwide          89.88          91.71
# 21                Cabot Oil & Gas          24.08          25.64
# 22                  Campbell Soup          44.22          43.94
# 23           Cardinal Health Inc.          64.34          72.27
# 24                     Carmax Inc          64.82          62.62
# 25             CenterPoint Energy          26.63          27.31
# 26                         Cerner          63.41          63.05
# 27             Cintas Corporation         156.46         176.13
# 28             The Clorox Company         127.00         131.19
# 29                     CMS Energy          42.37          42.96
# ..                            ...            ...            ...
# 124              Sherwin-Williams         392.38         413.77
# 125      Simon Property Group Inc         153.19         157.47
# 126            Southwest Airlines          56.87          60.33
# 127        Stanley Black & Decker         157.51         156.63
# 128                   Sysco Corp.          57.48          60.70
# 129          TE Connectivity Ltd.          98.33         104.62
# 130             Texas Instruments         104.21         110.59
# 131                  Textron Inc.          56.62          58.90
# 132                 Tiffany & Co.         100.74         101.29
# 133            TJX Companies Inc.          75.74          82.30
# 134         Total System Services          84.24          89.51
# 135                   TripAdvisor          35.62          42.28
# 136         United Parcel Service         112.35         109.33
# 137                    Unum Group          50.43          50.32
# 138                    V.F. Corp.          78.14          73.47
# 139        Varian Medical Systems         119.62         125.49
# 140                    Ventas Inc          52.88          50.35
# 141                   Viacom Inc.          30.95          32.60
# 142          Vornado Realty Trust          67.58          68.22
# 143              Vulcan Materials         124.91         121.67
# 144         Waste Management Inc.          81.30          86.66
# 145            Waters Corporation         203.26         212.13
# 146               Western Digital          81.45         102.91
# 147            Weyerhaeuser Corp.          34.47          35.55
# 148               Whirlpool Corp.         170.72         162.72
# 149                 Williams Cos.          29.11          28.02
# 150             Wyndham Worldwide         116.12         117.74
# 151                   Xerox Corp.          31.38          31.34
# 152                    Xilinx Inc          66.62          76.14
# 153                    Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0              67.98              75.93         7.95
# 1             190.27             219.76        29.49
# 2             180.95             177.44        -3.51
# 3             156.33             170.93        14.60
# 4              62.81              73.30        10.49
# 5             112.72             121.08         8.36
# 6             142.04             146.25         4.21
# 7              88.41              92.51         4.10
# 8              84.96              94.66         9.70
# 9             140.34             145.96         5.62
# 10             40.93              35.46        -5.47
# 11            113.45             117.39         3.94
# 12            159.02             161.52         2.50
# 13            113.36             115.91         2.55
# 14             36.42              41.62         5.20
# 15             65.37              68.09         2.72
# 16             68.02              71.52         3.50
# 17            328.31             283.24       -45.07
# 18             52.17              50.83        -1.34
# 19             26.40              28.43         2.03
# 20             89.88              91.71         1.83
# 21             24.08              25.64         1.56
# 22             44.22              43.94        -0.28
# 23             64.34              72.27         7.93
# 24             64.82              62.62        -2.20
# 25             26.63              27.31         0.68
# 26             63.41              63.05        -0.36
# 27            156.46             176.13        19.67
# 28            127.00             131.19         4.19
# 29             42.37              42.96         0.59
# ..               ...                ...          ...
# 124           392.38             413.77        21.39
# 125           153.19             157.47         4.28
# 126            56.87              60.33         3.46
# 127           157.51             156.63        -0.88
# 128            57.48              60.70         3.22
# 129            98.33             104.62         6.29
# 130           104.21             110.59         6.38
# 131            56.62              58.90         2.28
# 132           100.74             101.29         0.55
# 133            75.74              82.30         6.56
# 134            84.24              89.51         5.27
# 135            35.62              42.28         6.66
# 136           112.35             109.33        -3.02
# 137            50.43              50.32        -0.11
# 138            78.14              73.47        -4.67
# 139           119.62             125.49         5.87
# 140            52.88              50.35        -2.53
# 141            30.95              32.60         1.65
# 142            67.58              68.22         0.64
# 143           124.91             121.67        -3.24
# 144            81.30              86.66         5.36
# 145           203.26             212.13         8.87
# 146            81.45             102.91        21.46
# 147            34.47              35.55         1.08
# 148           170.72             162.72        -8.00
# 149            29.11              28.02        -1.09
# 150           116.12             117.74         1.62
# 151            31.38              31.34        -0.04
# 152            66.62              76.14         9.52
# 153            72.45              77.98         5.53
#
# [154 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using Penalized-SVM + Standard Scale Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_std_scale, X_test_std_scale, X_ver_std_scale = Standard_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_std_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
#X_train_std_scale_reduce, y_train_reduce = Down_Sample_Dataset(X_train_std_scale, y_train)

#model execution with SVM
df_result = SVM_Run(X_train_std_scale, y_train, X_test_std_scale, y_test, X_ver_std_scale, calc_return=True, penalized=True)
df_result.to_csv('SVM_Penalized_Std_Scale.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# SVC Default (accuracy) Train Dataset 0.630489651691
# SVC Default (accuracy) Test Dataset 0.588190764572
#
# SVC Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.58      0.93      0.71       730
#           1       0.65      0.17      0.27       591
#
# avg / total       0.61      0.59      0.52      1321
#
# SVC Default Confusion Matrix:
# ROC Curve
# AUROC Score: 0.656221988602
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$636.88]
# Total investment cost so far is [$15948.08]
# Total investment return so far is [$16584.96]
# Total investment return % gain so far is [0.03993458773720724%]
#
# Top 10 companies by investment profit:
# Top 10 Total investment cost so far is [$2122.8]
# Top 10 Total investment return so far is [$2422.6]
# Top 10 Total investment return % gain so far is [0.14122856604484643%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6        Sherwin-Williams         392.38         413.77           392.38
# 7             Intuit Inc.         157.65         177.68           157.65
# 8        KLA-Tencor Corp.         100.63         120.48           100.63
# 9      Cintas Corporation         156.46         176.13           156.46
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             413.77        21.39
# 7             177.68        20.03
# 8             120.48        19.85
# 9             176.13        19.67
#                           Company  Initial Price  Current Price  \
# 0                     AbbVie Inc.         109.51         119.75
# 1             Activision Blizzard          67.98          75.93
# 2               Adobe Systems Inc         190.27         219.76
# 3                       Aetna Inc         180.95         177.44
# 4    Air Products & Chemicals Inc         156.33         170.93
# 5         Akamai Technologies Inc          62.81          73.30
# 6         Alexion Pharmaceuticals         112.72         121.08
# 7                Altria Group Inc          65.34          65.43
# 8           American Tower Corp A         142.04         146.25
# 9                      Amgen Inc.         173.44         189.75
# 10                  Amphenol Corp          88.41          92.51
# 11           Analog Devices, Inc.          84.96          94.66
# 12                        Aon plc         140.34         145.96
# 13             Apache Corporation          40.93          35.46
# 14      Automatic Data Processing         113.45         117.39
# 15    AvalonBay Communities, Inc.         159.02         161.52
# 16            Avery Dennison Corp         113.36         115.91
# 17                      Ball Corp          36.42          41.62
# 18      Baxter International Inc.          65.37          68.09
# 19                    Biogen Inc.         328.31         283.24
# 20                     BorgWarner          52.17          50.83
# 21                Cabot Oil & Gas          24.08          25.64
# 22                  Campbell Soup          44.22          43.94
# 23           Cardinal Health Inc.          64.34          72.27
# 24                     Carmax Inc          64.82          62.62
# 25                  Celgene Corp.          93.74          91.56
# 26                         Cerner          63.41          63.05
# 27                    CIGNA Corp.         196.36         164.39
# 28             Cintas Corporation         156.46         176.13
# 29             The Clorox Company         127.00         131.19
# ..                            ...            ...            ...
# 123                    Sealed Air          44.30          44.74
# 124              Sherwin-Williams         392.38         413.77
# 125      Simon Property Group Inc         153.19         157.47
# 126        Stanley Black & Decker         157.51         156.63
# 127          TE Connectivity Ltd.          98.33         104.62
# 128             Texas Instruments         104.21         110.59
# 129                  Textron Inc.          56.62          58.90
# 130      Thermo Fisher Scientific         208.15         214.95
# 131                 Tiffany & Co.         100.74         101.29
# 132              Time Warner Inc.          95.39          96.16
# 133         Total System Services          84.24          89.51
# 134                   TripAdvisor          35.62          42.28
# 135                 Union Pacific         123.49         136.83
# 136      United Health Group Inc.         219.29         226.94
# 137         United Parcel Service         112.35         109.33
# 138                    Unum Group          50.43          50.32
# 139                    V.F. Corp.          78.14          73.47
# 140        Varian Medical Systems         119.62         125.49
# 141                    Ventas Inc          52.88          50.35
# 142                   Viacom Inc.          30.95          32.60
# 143          Vornado Realty Trust          67.58          68.22
# 144              Vulcan Materials         124.91         121.67
# 145         Waste Management Inc.          81.30          86.66
# 146            Weyerhaeuser Corp.          34.47          35.55
# 147               Whirlpool Corp.         170.72         162.72
# 148                 Williams Cos.          29.11          28.02
# 149             Wyndham Worldwide         116.12         117.74
# 150                   Xerox Corp.          31.38          31.34
# 151                    Xilinx Inc          66.62          76.14
# 152                    Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0             109.51             119.75        10.24
# 1              67.98              75.93         7.95
# 2             190.27             219.76        29.49
# 3             180.95             177.44        -3.51
# 4             156.33             170.93        14.60
# 5              62.81              73.30        10.49
# 6             112.72             121.08         8.36
# 7              65.34              65.43         0.09
# 8             142.04             146.25         4.21
# 9             173.44             189.75        16.31
# 10             88.41              92.51         4.10
# 11             84.96              94.66         9.70
# 12            140.34             145.96         5.62
# 13             40.93              35.46        -5.47
# 14            113.45             117.39         3.94
# 15            159.02             161.52         2.50
# 16            113.36             115.91         2.55
# 17             36.42              41.62         5.20
# 18             65.37              68.09         2.72
# 19            328.31             283.24       -45.07
# 20             52.17              50.83        -1.34
# 21             24.08              25.64         1.56
# 22             44.22              43.94        -0.28
# 23             64.34              72.27         7.93
# 24             64.82              62.62        -2.20
# 25             93.74              91.56        -2.18
# 26             63.41              63.05        -0.36
# 27            196.36             164.39       -31.97
# 28            156.46             176.13        19.67
# 29            127.00             131.19         4.19
# ..               ...                ...          ...
# 123            44.30              44.74         0.44
# 124           392.38             413.77        21.39
# 125           153.19             157.47         4.28
# 126           157.51             156.63        -0.88
# 127            98.33             104.62         6.29
# 128           104.21             110.59         6.38
# 129            56.62              58.90         2.28
# 130           208.15             214.95         6.80
# 131           100.74             101.29         0.55
# 132            95.39              96.16         0.77
# 133            84.24              89.51         5.27
# 134            35.62              42.28         6.66
# 135           123.49             136.83        13.34
# 136           219.29             226.94         7.65
# 137           112.35             109.33        -3.02
# 138            50.43              50.32        -0.11
# 139            78.14              73.47        -4.67
# 140           119.62             125.49         5.87
# 141            52.88              50.35        -2.53
# 142            30.95              32.60         1.65
# 143            67.58              68.22         0.64
# 144           124.91             121.67        -3.24
# 145            81.30              86.66         5.36
# 146            34.47              35.55         1.08
# 147           170.72             162.72        -8.00
# 148            29.11              28.02        -1.09
# 149           116.12             117.74         1.62
# 150            31.38              31.34        -0.04
# 151            66.62              76.14         9.52
# 152            72.45              77.98         5.53
#
# [153 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using GridSearch + Penalized-SVM + Standard Scale Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_std_scale, X_test_std_scale, X_ver_std_scale = Standard_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_std_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
#X_train_std_scale_reduce, y_train_reduce = Down_Sample_Dataset(X_train_std_scale, y_train)

#model execution with GridSearch Penalized-SVM
df_result = GridSearch_Penalized_SVM_Run(X_train_std_scale, y_train, X_test_std_scale, y_test, X_ver_std_scale, calc_return=True)
df_result.to_csv('GridSearch_Penalized_SVM_Std_Scale.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# GridSearch SVC Best Kernel: rbf
# GridSearch SVC Best C: 50
# GridSearch SVC Best gamma: 0.005
# GridSearch SVC Default (accuracy) Train Dataset 0.614336193841
# GridSearch SVC Default (accuracy) Test Dataset 0.572293716881
#
# GridSearch SVC Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.56      0.93      0.70       707
#           1       0.66      0.17      0.27       614
#
# avg / total       0.61      0.57      0.50      1321
#
# GridSearch SVC Default Confusion Matrix:
# GridSearch SVC ROC Curve
# AUROC Score: 0.655917667238
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$908.55]
# Total investment cost so far is [$15937.52]
# Total investment return so far is [$16846.07]
# Total investment return % gain so far is [0.05700698728534929%]
#
# Top 10 companies by investment profit:
# Top 10 Total investment cost so far is [$3100.63]
# Top 10 Total investment return so far is [$3583.28]
# Top 10 Total investment return % gain so far is [0.1556619138691169%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0         Amazon.com Inc.        1390.00        1588.18          1390.00
# 1            Netflix Inc.         254.26         315.88           254.26
# 2            Lam Research         169.92         223.97           169.92
# 3       Adobe Systems Inc         190.27         219.76           190.27
# 4            Red Hat Inc.         127.05         153.95           127.05
# 5              Apple Inc.         155.85         179.97           155.85
# 6    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 7  Northrop Grumman Corp.         321.33         344.33           321.33
# 8         Western Digital          81.45         102.91            81.45
# 9             Intuit Inc.         157.65         177.68           157.65
#
#    Investment Return  Profit/Loss
# 0            1588.18       198.18
# 1             315.88        61.62
# 2             223.97        54.05
# 3             219.76        29.49
# 4             153.95        26.90
# 5             179.97        24.12
# 6             276.65        23.80
# 7             344.33        23.00
# 8             102.91        21.46
# 9             177.68        20.03
#                                Company  Initial Price  Current Price  \
# 0                          AbbVie Inc.         109.51         119.75
# 1                  Activision Blizzard          67.98          75.93
# 2                    Adobe Systems Inc         190.27         219.76
# 3              Akamai Technologies Inc          62.81          73.30
# 4              Alexion Pharmaceuticals         112.72         121.08
# 5                     Altria Group Inc          65.34          65.43
# 6                      Amazon.com Inc.        1390.00        1588.18
# 7                American Tower Corp A         142.04         146.25
# 8                           Amgen Inc.         173.44         189.75
# 9                        Amphenol Corp          88.41          92.51
# 10                Analog Devices, Inc.          84.96          94.66
# 11                             Aon plc         140.34         145.96
# 12                          Apple Inc.         155.85         179.97
# 13           Automatic Data Processing         113.45         117.39
# 14         AvalonBay Communities, Inc.         159.02         161.52
# 15                 Avery Dennison Corp         113.36         115.91
# 16                           Ball Corp          36.42          41.62
# 17           Baxter International Inc.          65.37          68.09
# 18                         Biogen Inc.         328.31         283.24
# 19                          BorgWarner          52.17          50.83
# 20                   Boston Scientific          26.40          28.43
# 21                     Cabot Oil & Gas          24.08          25.64
# 22                       Campbell Soup          44.22          43.94
# 23                Cardinal Health Inc.          64.34          72.27
# 24                          Carmax Inc          64.82          62.62
# 25                       Celgene Corp.          93.74          91.56
# 26                     CenturyLink Inc          16.28          17.70
# 27                              Cerner          63.41          63.05
# 28                  Cintas Corporation         156.46         176.13
# 29                  The Clorox Company         127.00         131.19
# ..                                 ...            ...            ...
# 119  Scripps Networks Interactive Inc.          86.39          90.04
# 120                 Seagate Technology          49.65          59.68
# 121                         Sealed Air          44.30          44.74
# 122           Simon Property Group Inc         153.19         157.47
# 123             Stanley Black & Decker         157.51         156.63
# 124               TE Connectivity Ltd.          98.33         104.62
# 125                  Texas Instruments         104.21         110.59
# 126                       Textron Inc.          56.62          58.90
# 127           Thermo Fisher Scientific         208.15         214.95
# 128                      Tiffany & Co.         100.74         101.29
# 129                   Time Warner Inc.          95.39          96.16
# 130              Total System Services          84.24          89.51
# 131                        TripAdvisor          35.62          42.28
# 132                      Union Pacific         123.49         136.83
# 133                         Unum Group          50.43          50.32
# 134                         V.F. Corp.          78.14          73.47
# 135             Varian Medical Systems         119.62         125.49
# 136                         Ventas Inc          52.88          50.35
# 137                        Viacom Inc.          30.95          32.60
# 138               Vornado Realty Trust          67.58          68.22
# 139                   Vulcan Materials         124.91         121.67
# 140              Waste Management Inc.          81.30          86.66
# 141                    Western Digital          81.45         102.91
# 142                 Weyerhaeuser Corp.          34.47          35.55
# 143                    Whirlpool Corp.         170.72         162.72
# 144                      Williams Cos.          29.11          28.02
# 145                  Wyndham Worldwide         116.12         117.74
# 146                        Xerox Corp.          31.38          31.34
# 147                         Xilinx Inc          66.62          76.14
# 148                         Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0             109.51             119.75        10.24
# 1              67.98              75.93         7.95
# 2             190.27             219.76        29.49
# 3              62.81              73.30        10.49
# 4             112.72             121.08         8.36
# 5              65.34              65.43         0.09
# 6            1390.00            1588.18       198.18
# 7             142.04             146.25         4.21
# 8             173.44             189.75        16.31
# 9              88.41              92.51         4.10
# 10             84.96              94.66         9.70
# 11            140.34             145.96         5.62
# 12            155.85             179.97        24.12
# 13            113.45             117.39         3.94
# 14            159.02             161.52         2.50
# 15            113.36             115.91         2.55
# 16             36.42              41.62         5.20
# 17             65.37              68.09         2.72
# 18            328.31             283.24       -45.07
# 19             52.17              50.83        -1.34
# 20             26.40              28.43         2.03
# 21             24.08              25.64         1.56
# 22             44.22              43.94        -0.28
# 23             64.34              72.27         7.93
# 24             64.82              62.62        -2.20
# 25             93.74              91.56        -2.18
# 26             16.28              17.70         1.42
# 27             63.41              63.05        -0.36
# 28            156.46             176.13        19.67
# 29            127.00             131.19         4.19
# ..               ...                ...          ...
# 119            86.39              90.04         3.65
# 120            49.65              59.68        10.03
# 121            44.30              44.74         0.44
# 122           153.19             157.47         4.28
# 123           157.51             156.63        -0.88
# 124            98.33             104.62         6.29
# 125           104.21             110.59         6.38
# 126            56.62              58.90         2.28
# 127           208.15             214.95         6.80
# 128           100.74             101.29         0.55
# 129            95.39              96.16         0.77
# 130            84.24              89.51         5.27
# 131            35.62              42.28         6.66
# 132           123.49             136.83        13.34
# 133            50.43              50.32        -0.11
# 134            78.14              73.47        -4.67
# 135           119.62             125.49         5.87
# 136            52.88              50.35        -2.53
# 137            30.95              32.60         1.65
# 138            67.58              68.22         0.64
# 139           124.91             121.67        -3.24
# 140            81.30              86.66         5.36
# 141            81.45             102.91        21.46
# 142            34.47              35.55         1.08
# 143           170.72             162.72        -8.00
# 144            29.11              28.02        -1.09
# 145           116.12             117.74         1.62
# 146            31.38              31.34        -0.04
# 147            66.62              76.14         9.52
# 148            72.45              77.98         5.53
#
# [149 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using Penalized-SVM + Standard Scale  + PCA Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_std_scale, X_test_std_scale, X_ver_std_scale = Standard_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_std_scale)
X_train_std_scale_PCA, X_test_std_scale_PCA, X_ver_std_scale_PCA = PCA_Component_Selection(20, X_train_std_scale, X_test_std_scale, X_ver_std_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
#X_train_std_scale_PCA_reduce, y_train_reduce = Down_Sample_Dataset(X_train_std_scale_PCA, y_train)

#model execution with Logistic Regression
df_result = SVM_Run(X_train_std_scale_PCA, y_train, X_test_std_scale_PCA, y_test, X_ver_std_scale_PCA, calc_return=True, penalized=True)
df_result.to_csv('Panalized_SVM_Std_Scale_PCA.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# SVC Default (accuracy) Train Dataset 0.63301362948
# SVC Default (accuracy) Test Dataset 0.592732778198
#
# SVC Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.58      0.93      0.72       732
#           1       0.66      0.17      0.28       589
#
# avg / total       0.62      0.59      0.52      1321
#
# SVC Default Confusion Matrix:
# ROC Curve
# AUROC Score: 0.657865323964
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$696.04]
# Total investment cost so far is [$15969.19]
# Total investment return so far is [$16665.23]
# Total investment return % gain so far is [0.043586431121428196%]
#
# Top 10 companies by investment profit:
# Top 10 Total investment cost so far is [$2047.79]
# Top 10 Total investment return so far is [$2349.38]
# Top 10 Total investment return % gain so far is [0.14727584371444336%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6         Western Digital          81.45         102.91            81.45
# 7        Sherwin-Williams         392.38         413.77           392.38
# 8             Intuit Inc.         157.65         177.68           157.65
# 9        KLA-Tencor Corp.         100.63         120.48           100.63
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             102.91        21.46
# 7             413.77        21.39
# 8             177.68        20.03
# 9             120.48        19.85
#                           Company  Initial Price  Current Price  \
# 0                     AbbVie Inc.         109.51         119.75
# 1             Activision Blizzard          67.98          75.93
# 2               Adobe Systems Inc         190.27         219.76
# 3                       Aetna Inc         180.95         177.44
# 4    Air Products & Chemicals Inc         156.33         170.93
# 5         Akamai Technologies Inc          62.81          73.30
# 6         Alexion Pharmaceuticals         112.72         121.08
# 7                Altria Group Inc          65.34          65.43
# 8           American Tower Corp A         142.04         146.25
# 9                      Amgen Inc.         173.44         189.75
# 10                  Amphenol Corp          88.41          92.51
# 11           Analog Devices, Inc.          84.96          94.66
# 12                        Aon plc         140.34         145.96
# 13             Apache Corporation          40.93          35.46
# 14      Automatic Data Processing         113.45         117.39
# 15    AvalonBay Communities, Inc.         159.02         161.52
# 16            Avery Dennison Corp         113.36         115.91
# 17                      Ball Corp          36.42          41.62
# 18      Baxter International Inc.          65.37          68.09
# 19                    Biogen Inc.         328.31         283.24
# 20                     BorgWarner          52.17          50.83
# 21                Cabot Oil & Gas          24.08          25.64
# 22                  Campbell Soup          44.22          43.94
# 23           Cardinal Health Inc.          64.34          72.27
# 24                     Carmax Inc          64.82          62.62
# 25                  Celgene Corp.          93.74          91.56
# 26                         Cerner          63.41          63.05
# 27             Cintas Corporation         156.46         176.13
# 28             The Clorox Company         127.00         131.19
# 29                     CMS Energy          42.37          42.96
# ..                            ...            ...            ...
# 124              Sherwin-Williams         392.38         413.77
# 125      Simon Property Group Inc         153.19         157.47
# 126        Stanley Black & Decker         157.51         156.63
# 127          TE Connectivity Ltd.          98.33         104.62
# 128             Texas Instruments         104.21         110.59
# 129                  Textron Inc.          56.62          58.90
# 130      Thermo Fisher Scientific         208.15         214.95
# 131                 Tiffany & Co.         100.74         101.29
# 132              Time Warner Inc.          95.39          96.16
# 133         Total System Services          84.24          89.51
# 134                   TripAdvisor          35.62          42.28
# 135                 Union Pacific         123.49         136.83
# 136      United Health Group Inc.         219.29         226.94
# 137         United Parcel Service         112.35         109.33
# 138                    Unum Group          50.43          50.32
# 139                    V.F. Corp.          78.14          73.47
# 140        Varian Medical Systems         119.62         125.49
# 141                    Ventas Inc          52.88          50.35
# 142                   Viacom Inc.          30.95          32.60
# 143          Vornado Realty Trust          67.58          68.22
# 144              Vulcan Materials         124.91         121.67
# 145         Waste Management Inc.          81.30          86.66
# 146               Western Digital          81.45         102.91
# 147            Weyerhaeuser Corp.          34.47          35.55
# 148               Whirlpool Corp.         170.72         162.72
# 149                 Williams Cos.          29.11          28.02
# 150             Wyndham Worldwide         116.12         117.74
# 151                   Xerox Corp.          31.38          31.34
# 152                    Xilinx Inc          66.62          76.14
# 153                    Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0             109.51             119.75        10.24
# 1              67.98              75.93         7.95
# 2             190.27             219.76        29.49
# 3             180.95             177.44        -3.51
# 4             156.33             170.93        14.60
# 5              62.81              73.30        10.49
# 6             112.72             121.08         8.36
# 7              65.34              65.43         0.09
# 8             142.04             146.25         4.21
# 9             173.44             189.75        16.31
# 10             88.41              92.51         4.10
# 11             84.96              94.66         9.70
# 12            140.34             145.96         5.62
# 13             40.93              35.46        -5.47
# 14            113.45             117.39         3.94
# 15            159.02             161.52         2.50
# 16            113.36             115.91         2.55
# 17             36.42              41.62         5.20
# 18             65.37              68.09         2.72
# 19            328.31             283.24       -45.07
# 20             52.17              50.83        -1.34
# 21             24.08              25.64         1.56
# 22             44.22              43.94        -0.28
# 23             64.34              72.27         7.93
# 24             64.82              62.62        -2.20
# 25             93.74              91.56        -2.18
# 26             63.41              63.05        -0.36
# 27            156.46             176.13        19.67
# 28            127.00             131.19         4.19
# 29             42.37              42.96         0.59
# ..               ...                ...          ...
# 124           392.38             413.77        21.39
# 125           153.19             157.47         4.28
# 126           157.51             156.63        -0.88
# 127            98.33             104.62         6.29
# 128           104.21             110.59         6.38
# 129            56.62              58.90         2.28
# 130           208.15             214.95         6.80
# 131           100.74             101.29         0.55
# 132            95.39              96.16         0.77
# 133            84.24              89.51         5.27
# 134            35.62              42.28         6.66
# 135           123.49             136.83        13.34
# 136           219.29             226.94         7.65
# 137           112.35             109.33        -3.02
# 138            50.43              50.32        -0.11
# 139            78.14              73.47        -4.67
# 140           119.62             125.49         5.87
# 141            52.88              50.35        -2.53
# 142            30.95              32.60         1.65
# 143            67.58              68.22         0.64
# 144           124.91             121.67        -3.24
# 145            81.30              86.66         5.36
# 146            81.45             102.91        21.46
# 147            34.47              35.55         1.08
# 148           170.72             162.72        -8.00
# 149            29.11              28.02        -1.09
# 150           116.12             117.74         1.62
# 151            31.38              31.34        -0.04
# 152            66.62              76.14         9.52
# 153            72.45              77.98         5.53
#
# [154 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using GridSearch + Penalized-SVM + Standard Scale + PCA Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_std_scale, X_test_std_scale, X_ver_std_scale = Standard_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_std_scale)
X_train_std_scale_PCA, X_test_std_scale_PCA, X_ver_std_scale_PCA = PCA_Component_Selection(20, X_train_std_scale, X_test_std_scale, X_ver_std_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
#X_train_std_scale_PCA_reduce, y_train_reduce = Down_Sample_Dataset(X_train_std_scale_PCA, y_train)

#model execution with Logistic Regression
df_result = GridSearch_Penalized_SVM_Run(X_train_std_scale_PCA, y_train, X_test_std_scale_PCA, y_test, X_ver_std_scale_PCA, calc_return=True)
df_result.to_csv('GridSearch_Panalized_SVM_Std_Scale_PCA.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# GridSearch SVC Best Kernel: rbf
# GridSearch SVC Best C: 50
# GridSearch SVC Best gamma: 0.005
# GridSearch SVC Default (accuracy) Train Dataset 0.610297829379
# GridSearch SVC Default (accuracy) Test Dataset 0.57153671461
#
# GridSearch SVC Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.56      0.92      0.70       710
#           1       0.65      0.16      0.26       611
#
# avg / total       0.60      0.57      0.50      1321
#
# GridSearch SVC Default Confusion Matrix:
# GridSearch SVC ROC Curve
# AUROC Score: 0.652149615448
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$938.34]
# Total investment cost so far is [$16711.95]
# Total investment return so far is [$17650.29]
# Total investment return % gain so far is [0.05614784630159855%]
#
# Top 10 companies by investment profit:
# Top 10 Total investment cost so far is [$3335.36]
# Top 10 Total investment return so far is [$3819.37]
# Top 10 Total investment return % gain so far is [0.14511477021970642%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0         Amazon.com Inc.        1390.00        1588.18          1390.00
# 1            Netflix Inc.         254.26         315.88           254.26
# 2            Lam Research         169.92         223.97           169.92
# 3       Adobe Systems Inc         190.27         219.76           190.27
# 4            Red Hat Inc.         127.05         153.95           127.05
# 5              Apple Inc.         155.85         179.97           155.85
# 6    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 7  Northrop Grumman Corp.         321.33         344.33           321.33
# 8         Western Digital          81.45         102.91            81.45
# 9        Sherwin-Williams         392.38         413.77           392.38
#
#    Investment Return  Profit/Loss
# 0            1588.18       198.18
# 1             315.88        61.62
# 2             223.97        54.05
# 3             219.76        29.49
# 4             153.95        26.90
# 5             179.97        24.12
# 6             276.65        23.80
# 7             344.33        23.00
# 8             102.91        21.46
# 9             413.77        21.39
#                           Company  Initial Price  Current Price  \
# 0                     AbbVie Inc.         109.51         119.75
# 1             Activision Blizzard          67.98          75.93
# 2               Adobe Systems Inc         190.27         219.76
# 3                       Aetna Inc         180.95         177.44
# 4    Air Products & Chemicals Inc         156.33         170.93
# 5         Akamai Technologies Inc          62.81          73.30
# 6         Alexion Pharmaceuticals         112.72         121.08
# 7                Altria Group Inc          65.34          65.43
# 8                 Amazon.com Inc.        1390.00        1588.18
# 9           American Tower Corp A         142.04         146.25
# 10                     Amgen Inc.         173.44         189.75
# 11                  Amphenol Corp          88.41          92.51
# 12           Analog Devices, Inc.          84.96          94.66
# 13                        Aon plc         140.34         145.96
# 14                     Apple Inc.         155.85         179.97
# 15      Automatic Data Processing         113.45         117.39
# 16    AvalonBay Communities, Inc.         159.02         161.52
# 17            Avery Dennison Corp         113.36         115.91
# 18                      Ball Corp          36.42          41.62
# 19      Baxter International Inc.          65.37          68.09
# 20                    Biogen Inc.         328.31         283.24
# 21                     BorgWarner          52.17          50.83
# 22              Boston Scientific          26.40          28.43
# 23       C. H. Robinson Worldwide          89.88          91.71
# 24                Cabot Oil & Gas          24.08          25.64
# 25                  Campbell Soup          44.22          43.94
# 26           Cardinal Health Inc.          64.34          72.27
# 27                     Carmax Inc          64.82          62.62
# 28                  Celgene Corp.          93.74          91.56
# 29                CenturyLink Inc          16.28          17.70
# ..                            ...            ...            ...
# 122            Seagate Technology          49.65          59.68
# 123                    Sealed Air          44.30          44.74
# 124              Sherwin-Williams         392.38         413.77
# 125      Simon Property Group Inc         153.19         157.47
# 126        Stanley Black & Decker         157.51         156.63
# 127          TE Connectivity Ltd.          98.33         104.62
# 128                    TechnipFMC          31.83          30.34
# 129             Texas Instruments         104.21         110.59
# 130                  Textron Inc.          56.62          58.90
# 131      Thermo Fisher Scientific         208.15         214.95
# 132                 Tiffany & Co.         100.74         101.29
# 133         Total System Services          84.24          89.51
# 134                   TripAdvisor          35.62          42.28
# 135                 Union Pacific         123.49         136.83
# 136                    Unum Group          50.43          50.32
# 137                    V.F. Corp.          78.14          73.47
# 138        Varian Medical Systems         119.62         125.49
# 139                    Ventas Inc          52.88          50.35
# 140                   Viacom Inc.          30.95          32.60
# 141          Vornado Realty Trust          67.58          68.22
# 142              Vulcan Materials         124.91         121.67
# 143         Waste Management Inc.          81.30          86.66
# 144               Western Digital          81.45         102.91
# 145            Weyerhaeuser Corp.          34.47          35.55
# 146               Whirlpool Corp.         170.72         162.72
# 147                 Williams Cos.          29.11          28.02
# 148             Wyndham Worldwide         116.12         117.74
# 149                   Xerox Corp.          31.38          31.34
# 150                    Xilinx Inc          66.62          76.14
# 151                    Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0             109.51             119.75        10.24
# 1              67.98              75.93         7.95
# 2             190.27             219.76        29.49
# 3             180.95             177.44        -3.51
# 4             156.33             170.93        14.60
# 5              62.81              73.30        10.49
# 6             112.72             121.08         8.36
# 7              65.34              65.43         0.09
# 8            1390.00            1588.18       198.18
# 9             142.04             146.25         4.21
# 10            173.44             189.75        16.31
# 11             88.41              92.51         4.10
# 12             84.96              94.66         9.70
# 13            140.34             145.96         5.62
# 14            155.85             179.97        24.12
# 15            113.45             117.39         3.94
# 16            159.02             161.52         2.50
# 17            113.36             115.91         2.55
# 18             36.42              41.62         5.20
# 19             65.37              68.09         2.72
# 20            328.31             283.24       -45.07
# 21             52.17              50.83        -1.34
# 22             26.40              28.43         2.03
# 23             89.88              91.71         1.83
# 24             24.08              25.64         1.56
# 25             44.22              43.94        -0.28
# 26             64.34              72.27         7.93
# 27             64.82              62.62        -2.20
# 28             93.74              91.56        -2.18
# 29             16.28              17.70         1.42
# ..               ...                ...          ...
# 122            49.65              59.68        10.03
# 123            44.30              44.74         0.44
# 124           392.38             413.77        21.39
# 125           153.19             157.47         4.28
# 126           157.51             156.63        -0.88
# 127            98.33             104.62         6.29
# 128            31.83              30.34        -1.49
# 129           104.21             110.59         6.38
# 130            56.62              58.90         2.28
# 131           208.15             214.95         6.80
# 132           100.74             101.29         0.55
# 133            84.24              89.51         5.27
# 134            35.62              42.28         6.66
# 135           123.49             136.83        13.34
# 136            50.43              50.32        -0.11
# 137            78.14              73.47        -4.67
# 138           119.62             125.49         5.87
# 139            52.88              50.35        -2.53
# 140            30.95              32.60         1.65
# 141            67.58              68.22         0.64
# 142           124.91             121.67        -3.24
# 143            81.30              86.66         5.36
# 144            81.45             102.91        21.46
# 145            34.47              35.55         1.08
# 146           170.72             162.72        -8.00
# 147            29.11              28.02        -1.09
# 148           116.12             117.74         1.62
# 149            31.38              31.34        -0.04
# 150            66.62              76.14         9.52
# 151            72.45              77.98         5.53
#
# [152 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using SVM + MinMax Scale + Down-Sampling Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_mm_scale, X_test_mm_scale, X_ver_mm_scale = MinMax_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_mm_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
X_train_mm_scale_reduce, y_train_reduce = Down_Sample_Dataset(X_train_mm_scale, y_train)

#model execution with SVM
df_result = SVM_Run(X_train_mm_scale_reduce, y_train_reduce, X_test_mm_scale, y_test, X_ver_mm_scale, calc_return=True, penalized=False)
df_result.to_csv('SVM_mm_Scale_Down_Sampling.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# Y before down-sampling: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y after down-sampling: (array([0, 1], dtype=int64), array([461, 461], dtype=int64))
# SVC Default (accuracy) Train Dataset 0.546637744035
# SVC Default (accuracy) Test Dataset 0.208932626798
#
# SVC Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.11      0.97      0.19       129
#           1       0.97      0.13      0.22      1192
#
# avg / total       0.89      0.21      0.22      1321
#
# SVC Default Confusion Matrix:
# ROC Curve
# AUROC Score: 0.621485088253
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$872.51]
# Total investment cost so far is [$22489.17]
# Total investment return so far is [$23361.68]
# Total investment return % gain so far is [0.03879689646171913%]
#
# Top 10 companies by investment profit:
# Top 10 Total investment cost so far is [$2195.57]
# Top 10 Total investment return so far is [$2497.43]
# Top 10 Total investment return % gain so far is [0.13748593759251584%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6         Western Digital          81.45         102.91            81.45
# 7        Sherwin-Williams         392.38         413.77           392.38
# 8     Goldman Sachs Group         248.41         268.53           248.41
# 9             Intuit Inc.         157.65         177.68           157.65
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             102.91        21.46
# 7             413.77        21.39
# 8             268.53        20.12
# 9             177.68        20.03
#                           Company  Initial Price  Current Price  \
# 0             Abbott Laboratories          58.73          63.20
# 1                     AbbVie Inc.         109.51         119.75
# 2                   Accenture plc         151.83         162.49
# 3             Activision Blizzard          67.98          75.93
# 4               Adobe Systems Inc         190.27         219.76
# 5      Advanced Micro Devices Inc          11.57          11.64
# 6                       Aetna Inc         180.95         177.44
# 7                       AFLAC Inc          85.71          90.75
# 8    Air Products & Chemicals Inc         156.33         170.93
# 9         Akamai Technologies Inc          62.81          73.30
# 10        Alexion Pharmaceuticals         112.72         121.08
# 11                  Allstate Corp          94.55          96.41
# 12               Altria Group Inc          65.34          65.43
# 13                    Ameren Corp          53.69          54.09
# 14            American Express Co          92.01          95.37
# 15          American Tower Corp A         142.04         146.25
# 16         AmerisourceBergen Corp          91.54         100.60
# 17                     Amgen Inc.         173.44         189.75
# 18                  Amphenol Corp          88.41          92.51
# 19           Analog Devices, Inc.          84.96          94.66
# 20                        Aon plc         140.34         145.96
# 21             Apache Corporation          40.93          35.46
# 22         Applied Materials Inc.          48.22          59.69
# 23      Archer-Daniels-Midland Co          40.29          44.24
# 24                  Assurant Inc.          87.62          89.10
# 25      Automatic Data Processing         113.45         117.39
# 26    AvalonBay Communities, Inc.         159.02         161.52
# 27            Avery Dennison Corp         113.36         115.91
# 28                      Ball Corp          36.42          41.62
# 29      Baxter International Inc.          65.37          68.09
# ..                            ...            ...            ...
# 207      Thermo Fisher Scientific         208.15         214.95
# 208                 Tiffany & Co.         100.74         101.29
# 209              Time Warner Inc.          95.39          96.16
# 210            TJX Companies Inc.          75.74          82.30
# 211         Total System Services          84.24          89.51
# 212  The Travelers Companies Inc.         140.79         140.69
# 213                   TripAdvisor          35.62          42.28
# 214                 Union Pacific         123.49         136.83
# 215         United Parcel Service         112.35         109.33
# 216           United Technologies         126.54         130.15
# 217                    Unum Group          50.43          50.32
# 218                    V.F. Corp.          78.14          73.47
# 219        Varian Medical Systems         119.62         125.49
# 220                    Ventas Inc          52.88          50.35
# 221                   Viacom Inc.          30.95          32.60
# 222          Vornado Realty Trust          67.58          68.22
# 223              Vulcan Materials         124.91         121.67
# 224       The Walt Disney Company         104.70         103.73
# 225         Waste Management Inc.          81.30          86.66
# 226            Waters Corporation         203.26         212.13
# 227          Wec Energy Group Inc          60.62          60.80
# 228               Western Digital          81.45         102.91
# 229            Weyerhaeuser Corp.          34.47          35.55
# 230               Whirlpool Corp.         170.72         162.72
# 231                 Williams Cos.          29.11          28.02
# 232             Wyndham Worldwide         116.12         117.74
# 233               Xcel Energy Inc          43.25          43.13
# 234                   Xerox Corp.          31.38          31.34
# 235                    Xilinx Inc          66.62          76.14
# 236                    Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0              58.73              63.20         4.47
# 1             109.51             119.75        10.24
# 2             151.83             162.49        10.66
# 3              67.98              75.93         7.95
# 4             190.27             219.76        29.49
# 5              11.57              11.64         0.07
# 6             180.95             177.44        -3.51
# 7              85.71              90.75         5.04
# 8             156.33             170.93        14.60
# 9              62.81              73.30        10.49
# 10            112.72             121.08         8.36
# 11             94.55              96.41         1.86
# 12             65.34              65.43         0.09
# 13             53.69              54.09         0.40
# 14             92.01              95.37         3.36
# 15            142.04             146.25         4.21
# 16             91.54             100.60         9.06
# 17            173.44             189.75        16.31
# 18             88.41              92.51         4.10
# 19             84.96              94.66         9.70
# 20            140.34             145.96         5.62
# 21             40.93              35.46        -5.47
# 22             48.22              59.69        11.47
# 23             40.29              44.24         3.95
# 24             87.62              89.10         1.48
# 25            113.45             117.39         3.94
# 26            159.02             161.52         2.50
# 27            113.36             115.91         2.55
# 28             36.42              41.62         5.20
# 29             65.37              68.09         2.72
# ..               ...                ...          ...
# 207           208.15             214.95         6.80
# 208           100.74             101.29         0.55
# 209            95.39              96.16         0.77
# 210            75.74              82.30         6.56
# 211            84.24              89.51         5.27
# 212           140.79             140.69        -0.10
# 213            35.62              42.28         6.66
# 214           123.49             136.83        13.34
# 215           112.35             109.33        -3.02
# 216           126.54             130.15         3.61
# 217            50.43              50.32        -0.11
# 218            78.14              73.47        -4.67
# 219           119.62             125.49         5.87
# 220            52.88              50.35        -2.53
# 221            30.95              32.60         1.65
# 222            67.58              68.22         0.64
# 223           124.91             121.67        -3.24
# 224           104.70             103.73        -0.97
# 225            81.30              86.66         5.36
# 226           203.26             212.13         8.87
# 227            60.62              60.80         0.18
# 228            81.45             102.91        21.46
# 229            34.47              35.55         1.08
# 230           170.72             162.72        -8.00
# 231            29.11              28.02        -1.09
# 232           116.12             117.74         1.62
# 233            43.25              43.13        -0.12
# 234            31.38              31.34        -0.04
# 235            66.62              76.14         9.52
# 236            72.45              77.98         5.53
#
# [237 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using GridSearch + Penalized-SVM + MinMax Scale + PCA Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_mm_scale, X_test_mm_scale, X_ver_mm_scale = MinMax_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_mm_scale)
X_train_mm_scale_PCA, X_test_mm_scale_PCA, X_ver_mm_scale_PCA = PCA_Component_Selection(20, X_train_mm_scale, X_test_mm_scale, X_ver_mm_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
#X_train_mm_scale_PCA_reduce, y_train_reduce = Down_Sample_Dataset(X_train_mm_scale_PCA, y_train)

#model execution with GridSearch Penalized SVM
df_result = GridSearch_Penalized_SVM_Run(X_train_mm_scale_PCA, y_train, X_test_mm_scale_PCA, y_test, X_ver_mm_scale_PCA, calc_return=True)
df_result.to_csv('GridSearch_Penalized_SVM_mm_Scale_PCA.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# GridSearch SVC Best Kernel: rbf
# GridSearch SVC Best C: 1
# GridSearch SVC Best gamma: 0.0001
# GridSearch SVC Default (accuracy) Train Dataset 0.116355376073
# GridSearch SVC Default (accuracy) Test Dataset 0.117335352006
#
# GridSearch SVC Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       1.00      0.12      0.21      1321
#
# avg / total       1.00      0.12      0.21      1321
#
# GridSearch SVC Default Confusion Matrix:
# C:\Users\clau3\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# GridSearch SVC ROC Curve
# AUROC Score: 0.377839871632
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$1210.32]
# Total investment cost so far is [$25973.14]
# Total investment return so far is [$27183.46]
# Total investment return % gain so far is [0.04659890948880266%]
#
# Top 10 companies by investment profit:
# Top 10 Total investment cost so far is [$3998.78]
# Top 10 Total investment return so far is [$4543.77]
# Top 10 Total investment return % gain so far is [0.13628906816579056%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0         Amazon.com Inc.        1390.00        1588.18          1390.00
# 1    Alphabet Inc Class C        1055.80        1138.17          1055.80
# 2            Netflix Inc.         254.26         315.88           254.26
# 3            Lam Research         169.92         223.97           169.92
# 4       Adobe Systems Inc         190.27         219.76           190.27
# 5            Red Hat Inc.         127.05         153.95           127.05
# 6              Apple Inc.         155.85         179.97           155.85
# 7    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 8  Northrop Grumman Corp.         321.33         344.33           321.33
# 9         Western Digital          81.45         102.91            81.45
#
#    Investment Return  Profit/Loss
# 0            1588.18       198.18
# 1            1138.17        82.37
# 2             315.88        61.62
# 3             223.97        54.05
# 4             219.76        29.49
# 5             153.95        26.90
# 6             179.97        24.12
# 7             276.65        23.80
# 8             344.33        23.00
# 9             102.91        21.46
#                           Company  Initial Price  Current Price  \
# 0             Abbott Laboratories          58.73          63.20
# 1                     AbbVie Inc.         109.51         119.75
# 2                   Accenture plc         151.83         162.49
# 3             Activision Blizzard          67.98          75.93
# 4               Adobe Systems Inc         190.27         219.76
# 5      Advanced Micro Devices Inc          11.57          11.64
# 6                       Aetna Inc         180.95         177.44
# 7                       AFLAC Inc          85.71          90.75
# 8    Air Products & Chemicals Inc         156.33         170.93
# 9         Akamai Technologies Inc          62.81          73.30
# 10        Alexion Pharmaceuticals         112.72         121.08
# 11                  Allstate Corp          94.55          96.41
# 12           Alphabet Inc Class C        1055.80        1138.17
# 13               Altria Group Inc          65.34          65.43
# 14                Amazon.com Inc.        1390.00        1588.18
# 15                    Ameren Corp          53.69          54.09
# 16            American Express Co          92.01          95.37
# 17          American Tower Corp A         142.04         146.25
# 18         AmerisourceBergen Corp          91.54         100.60
# 19                     Amgen Inc.         173.44         189.75
# 20                  Amphenol Corp          88.41          92.51
# 21           Analog Devices, Inc.          84.96          94.66
# 22                        Aon plc         140.34         145.96
# 23             Apache Corporation          40.93          35.46
# 24                     Apple Inc.         155.85         179.97
# 25         Applied Materials Inc.          48.22          59.69
# 26      Archer-Daniels-Midland Co          40.29          44.24
# 27                  Assurant Inc.          87.62          89.10
# 28                      AT&T Inc.          36.63          37.39
# 29      Automatic Data Processing         113.45         117.39
# ..                            ...            ...            ...
# 221              Time Warner Inc.          95.39          96.16
# 222            TJX Companies Inc.          75.74          82.30
# 223         Total System Services          84.24          89.51
# 224  The Travelers Companies Inc.         140.79         140.69
# 225                   TripAdvisor          35.62          42.28
# 226                 Union Pacific         123.49         136.83
# 227      United Health Group Inc.         219.29         226.94
# 228         United Parcel Service         112.35         109.33
# 229           United Technologies         126.54         130.15
# 230                    Unum Group          50.43          50.32
# 231                    V.F. Corp.          78.14          73.47
# 232        Varian Medical Systems         119.62         125.49
# 233                    Ventas Inc          52.88          50.35
# 234        Verizon Communications          50.50          48.65
# 235                   Viacom Inc.          30.95          32.60
# 236          Vornado Realty Trust          67.58          68.22
# 237              Vulcan Materials         124.91         121.67
# 238       The Walt Disney Company         104.70         103.73
# 239         Waste Management Inc.          81.30          86.66
# 240            Waters Corporation         203.26         212.13
# 241          Wec Energy Group Inc          60.62          60.80
# 242               Western Digital          81.45         102.91
# 243            Weyerhaeuser Corp.          34.47          35.55
# 244               Whirlpool Corp.         170.72         162.72
# 245                 Williams Cos.          29.11          28.02
# 246             Wyndham Worldwide         116.12         117.74
# 247               Xcel Energy Inc          43.25          43.13
# 248                   Xerox Corp.          31.38          31.34
# 249                    Xilinx Inc          66.62          76.14
# 250                    Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0              58.73              63.20         4.47
# 1             109.51             119.75        10.24
# 2             151.83             162.49        10.66
# 3              67.98              75.93         7.95
# 4             190.27             219.76        29.49
# 5              11.57              11.64         0.07
# 6             180.95             177.44        -3.51
# 7              85.71              90.75         5.04
# 8             156.33             170.93        14.60
# 9              62.81              73.30        10.49
# 10            112.72             121.08         8.36
# 11             94.55              96.41         1.86
# 12           1055.80            1138.17        82.37
# 13             65.34              65.43         0.09
# 14           1390.00            1588.18       198.18
# 15             53.69              54.09         0.40
# 16             92.01              95.37         3.36
# 17            142.04             146.25         4.21
# 18             91.54             100.60         9.06
# 19            173.44             189.75        16.31
# 20             88.41              92.51         4.10
# 21             84.96              94.66         9.70
# 22            140.34             145.96         5.62
# 23             40.93              35.46        -5.47
# 24            155.85             179.97        24.12
# 25             48.22              59.69        11.47
# 26             40.29              44.24         3.95
# 27             87.62              89.10         1.48
# 28             36.63              37.39         0.76
# 29            113.45             117.39         3.94
# ..               ...                ...          ...
# 221            95.39              96.16         0.77
# 222            75.74              82.30         6.56
# 223            84.24              89.51         5.27
# 224           140.79             140.69        -0.10
# 225            35.62              42.28         6.66
# 226           123.49             136.83        13.34
# 227           219.29             226.94         7.65
# 228           112.35             109.33        -3.02
# 229           126.54             130.15         3.61
# 230            50.43              50.32        -0.11
# 231            78.14              73.47        -4.67
# 232           119.62             125.49         5.87
# 233            52.88              50.35        -2.53
# 234            50.50              48.65        -1.85
# 235            30.95              32.60         1.65
# 236            67.58              68.22         0.64
# 237           124.91             121.67        -3.24
# 238           104.70             103.73        -0.97
# 239            81.30              86.66         5.36
# 240           203.26             212.13         8.87
# 241            60.62              60.80         0.18
# 242            81.45             102.91        21.46
# 243            34.47              35.55         1.08
# 244           170.72             162.72        -8.00
# 245            29.11              28.02        -1.09
# 246           116.12             117.74         1.62
# 247            43.25              43.13        -0.12
# 248            31.38              31.34        -0.04
# 249            66.62              76.14         9.52
# 250            72.45              77.98         5.53
#
# [251 rows x 6 columns]

# %% [markdown]
# ### Conclusion

# %% [markdown]
# With Support Vector Machine, the best estimated model is using the combination of:
#
# "Stock Analysis using GridSearch + Penalized-SVM + Standard Scale Data"
#
# with
#
# - GridSearch SVC Best Kernel: rbf
# - GridSearch SVC Best C: 50
# - GridSearch SVC Best gamma: 0.005
# - GridSearch SVC Default (accuracy) Train Dataset 0.614336193841
# - GridSearch SVC Default (accuracy) Test Dataset 0.572293716881
#
# - GridSearch SVC Default Metric Report:
#                  precision    recall  f1-score   support
#
#               0       0.56      0.93      0.70       707
#               1       0.66      0.17      0.27       614
#
#         avg / total   0.61      0.57      0.50      1321
#
# - AUROC Score: 0.655917667238
# - Top 10 investments total return % gain from [2018-02-05] till [2018-03-13] is 15.57%
#
# | Company         |
# |---------------  |
# | `Amazon.com Inc.`	  |
# | `Netflix Inc.` |
# | `Lam Research`        |
# | `Adobe Systems Inc`   |
# | `Red Hat Inc.`   |
# | `Apple Inc.`   |
# | `Grainger (W.W.) Inc.`   |
# | `Northrop Grumman Corp.`   |
# | `Western Digital`   |
# | `Intuit Inc.`   |
