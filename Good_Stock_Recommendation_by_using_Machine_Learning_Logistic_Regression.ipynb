# %% [markdown]
# ## 1. Logistic Regression

# %%
#import library
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import datetime
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

#analysis target
how_much_better = 10
invest_unit_per_stock = 1
current_key_stats = datetime.datetime(2018, 2, 5, 0, 0)

#analysis features
Analysis_Features = [
                     'Market Cap',
                     'Enterprise Value',
                     'Trailing P/E',
                     'Forward P/E',
                     'PEG Ratio',
                     'Price/Sales',
                     'Enterprise Value/Revenue',
                     'Profit Margin',
                     'Operating Margin', 
                     'Return on Equity',
                     'Revenue',
                     'Revenue Per Share',                         
                     'Net Income Avl to Common',
                     'Diluted EPS',
                     'Total Cash',
                     'Total Cash Per Share',
                     'Total Debt',
                     'Book Value Per Share',
                     'Operating Cash Flow',
                     'Beta',
                     '% Held by Insiders',
                     '% Held by Institutions',
                     'Shares Short', 
                     'Short Ratio'
                    ]

# %% [markdown]
# ### Stock ranking

# %%
#define function to rank stock based on differences between stock price changes & S&P 500 index changes
def Rank_Stock(row):  
    if row['Stock Price vs S&P 500 Index'] > how_much_better:
        #print(row['Ticker'], row['Stock Price vs S&P 500 Index'])
        return 1
    else:
        return 0
    
#define function to rank stock based on differences compare to its previous price
def Rank_Stock_By_Historical(row):
    if row["Stock Price Change"] > how_much_better:
        #print(row['Ticker'], row["Stock Price Change"])
        return 1
    else:
        return 0

# %% [markdown]
# ### Data load

# %%
#define function to load historical data
def Load_Historical_Data():
    historical_data_path = os.path.join(os.path.join(os.getcwd(), 'Data'), "Historical.csv")
    df = pd.read_csv(historical_data_path, sep=',')#.iloc[:,1:]
    return df

#define function to load forward data
def Load_Forward_Data():
    forward_data_path = os.path.join(os.path.join(os.getcwd(), 'Data'), "Forward.csv")
    df = pd.read_csv(forward_data_path, sep=',')#.iloc[:,1:]
    return df

# %% [markdown]
# ### Load Yahoo Finance stock price

# %%
#using 3rd party code from https://github.com/c0redumb/yahoo_quote_download to download stock price from Yahoo Finance
import yahoo_quote_download as yqd
from datetime import datetime, timedelta
import pandas as pd

def load_quote(ticker, startDate, endDate, search_method='F', count=0):
    count+=1
#     if startDate.weekday() == 5:
#         startDate = startDate + timedelta(days=2)
#     elif startDate.weekday() == 6:
#         startDate = startDate + timedelta(days=1)
        
#     if endDate.weekday() == 5:
#         endDate = endDate + timedelta(days=2)
#     elif endDate.weekday() == 6:
#         endDate = endDate + timedelta(days=1)
        
    start = startDate.strftime('%Y%m%d')
    end = endDate.strftime('%Y%m%d')    
    data = yqd.load_yahoo_quote(ticker, start, end)   
#     print('===', ticker, start, end, search_method, count, data,'===')
    df = pd.DataFrame([sub.split(",") for sub in data if len(sub.split(",")[0])>0 and sub.split(",")[0] != 'Date'], columns=['Date','Open','High','Low','Close','Adj Close','Volume'])    
      
    if len(df) == 0 and count < 10:
        value = None
        if search_method=='F':
            startDate = startDate + timedelta(days=1)
            endDate = endDate + timedelta(days=1)
        else:
            startDate = startDate - timedelta(days=1)
            endDate = endDate - timedelta(days=1)
            
        return load_quote(ticker, startDate, endDate, search_method, count)
    else:        
        value = df.iloc[0]['Adj Close'] if len(df) > 0 else None
    return value#df

# %%
import datetime
import time
t1 = datetime.datetime(2018, 2, 5, 0, 0)
t1.date()

ticker = 'ACN'
# df = load_quote(ticker, t1, t1)
# print(df)

d = datetime.date.today()-timedelta(days=1)
d

df = load_quote(ticker, d,d, search_method='B')  
df

# now = datetime.date.today()-timedelta(days=1)
# now
#currentDate = datetime.datetime.strptime('01/08/2015','%d/%m/%Y').date()
# Out:
# '162.490005'

# %% [markdown]
# ### Check for NaN value in data

# %%
def Check_Null_Data(df):
    #check for NaN data   
    #as there're a lot of N/A data, cautious approach will be implemented for stock analysis to follow rules of:
    #1) Avoid loss 
    #2) Do not forget rule#1
    #All N/A data found in key features used for analysis will be removed.
    return df.isnull().sum()

# %% [markdown]
# ### Data cleaning and null value handling

# %%
#define function to preprocess data
def Historical_Data_Preprocessing_All_Industry(df, ranking=0): 
    #df = Load_Historical_Data()
    
    #drop row with any NA value based on Analysis Features + Stock Price 
    df = df.dropna(subset=['Stock Price']+Analysis_Features, how='any').reset_index().drop(['index'], axis=1)  
        
    #features data set
    X = df[Analysis_Features]  
    
    #label data set    
    if ranking==0:
        df['Ranking'] = df.apply(Rank_Stock, axis=1)
    else:
        df['Ranking'] = df.apply(Rank_Stock_By_Historical, axis=1)
    y = df['Ranking']
    
    return X,y

#define function to preprocess data
def Forward_Data_Preprocessing_All_Industry(df): 
    #df = Load_Forward_Data()
    
    #drop row with any NA value based on Analysis Features + Stock Price 
    df = df.dropna(subset=['Ticker','Security','GICS Sector','GICS Sub Industry']+Analysis_Features, how='any').reset_index().drop(['index'], axis=1)
       
    #features data set
    X = df[Analysis_Features]
    
    #Listed company data set 
    z = df[['Ticker','Security','GICS Sector','GICS Sub Industry']]    
        
    return X,z

# %% [markdown]
# ### Train and Test Dataset Split

# %%
from sklearn.model_selection import train_test_split

def Train_Test_Split(X, y):
    #For the sake of testing our classifier output, we will split the data into a training and testing set
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
    #X_columns = list(X_train)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### Feature Scaling and Normalization

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

def Standard_Scale(X_train, X_test, X_ver):
    scaler = StandardScaler()
    #standard scale transform
    X_train_std_scale = scaler.fit_transform(X_train)
    X_test_std_scale = scaler.transform(X_test)
    X_ver_std_scale = scaler.transform(X_ver)
    return X_train_std_scale, X_test_std_scale, X_ver_std_scale

def MinMax_Scale(X_train, X_test, X_ver):
    scaler = MinMaxScaler()
    #MinMax scale transform
    X_train_mm_scale = scaler.fit_transform(X_train)
    X_test_mm_scale = scaler.transform(X_test)
    X_ver_mm_scale = scaler.transform(X_ver)
    return X_train_mm_scale, X_test_mm_scale, X_ver_mm_scale

# %% [markdown]
# ### PCA - choosing number of components

# %%
from sklearn.decomposition import PCA

def PCA_Component_Analysis(X_train):
    pca = PCA()
    X_train_PCA = pca.fit_transform(X_train) #fit_transform X_train

    plt.plot(np.cumsum(pca.explained_variance_ratio_))
    plt.xlabel('number of components')
    plt.ylabel('cumulative explained variance');
    plt.show();
    
def PCA_Component_Selection(n_components, X_train, X_test, X_ver):
    #choose 15 components for PCA to reduce features
    pca = PCA(n_components=n_components)

    X_train_PCA = pca.fit_transform(X_train)
    X_test_PCA = pca.transform(X_test)
    X_ver_PCA = pca.transform(X_ver)
    return X_train_PCA, X_test_PCA, X_ver_PCA

# %% [markdown]
# ### Imbalance dataset handling

# %%
from imblearn.under_sampling import RandomUnderSampler

def Down_Sample_Dataset(X, y):  
    rus = RandomUnderSampler(return_indices=True, random_state=42)
    X_undersampling, y_undersampling, idx_resampled = rus.fit_sample(X, y)
    print('Y before down-sampling:', np.unique(y,return_counts=True))
    print('Y after down-sampling:', np.unique(y_undersampling,return_counts=True))
    return X_undersampling, y_undersampling

# %% [markdown]
# ### Model Execution with Logistic Regression

# %%
def Logistic_Regression_Run(X_train, y_train, X_test, y_test, X_ver, calc_return=True):
    #Logistic Regression 
    from sklearn.linear_model import LogisticRegression
    model = LogisticRegression().fit(X_train, y_train)

    # Logistic Regression Default accuracy 
    print('Logistic Regression Default (accuracy) Train Dataset', model.score(X_train, y_train))
    print('Logistic Regression Default (accuracy) Test Dataset', model.score(X_test, y_test))
    print()

    # Logistic Regression Default metric report
    from sklearn import metrics
    y_pred = model.predict(X_test)
    print('Logistic Regression Default Metric Report:')
    print(metrics.classification_report(y_pred, y_test))

    # Logistic Regression Default Confusion Matrix
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    print('Logistic Regression Default Confusion Matrix:')
    mat = confusion_matrix(y_test, y_pred)
    sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
    plt.xlabel('true label')
    plt.ylabel('predicted label')
    plt.show();

    # Calculate AUROC
    from sklearn.metrics import roc_auc_score
    y_prob = model.predict_proba(X_test)
    y_prob = [p[1] for p in y_prob]

    from sklearn.metrics import roc_curve, auc
    fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label=1)
    auc_result = auc(fpr, tpr)
    print('ROC Curve')
    print('AUROC Score:',roc_auc_score(y_test, y_prob))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='area = {0:0.2f}'.format(auc_result))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()

    #test with latest stock key statistic
    import datetime
    print('Predict using latest Key Statistic @ {0}'.format(current_key_stats.strftime('%Y-%m-%d')))    
    y_pred = model.predict(X_ver)

    counter=0
    invest_list = []
    initial_price = []
    current_price = []
    investment_cost = []
    investment_return = []
    profit_loss = []
    for t in y_pred:   
         if t == 1:                
            invest_list.append(z.iloc[counter]['Security'])            
            if calc_return == True:        
                ini_price = load_quote(z.iloc[counter]['Ticker'],current_key_stats,current_key_stats, search_method='F')        
                cur_price = load_quote(z.iloc[counter]['Ticker'],datetime.date.today()-timedelta(days=1),datetime.date.today()-timedelta(days=1), search_method='B')  
                if ini_price != None:
                    ini_price = round(float(ini_price),2)
                    inv_cost = round(float(ini_price)*invest_unit_per_stock,2)
                else:
                    inv_cost = None
                if cur_price != None:
                    cur_price = round(float(cur_price),2)
                    inv_return = round(float(cur_price)*invest_unit_per_stock,2)
                else:
                    inv_return = None
                if inv_cost != None and inv_return != None:
                    pl = round(inv_return-inv_cost,2)
                else:
                    pl = None
                
                initial_price.append(ini_price)
                current_price.append(cur_price)
                investment_cost.append(inv_cost)
                investment_return.append(inv_return)
                profit_loss.append(pl)
         counter+=1
    
    print()
    if calc_return == True:
        df_rcmd = pd.DataFrame({
                                'Company':invest_list,
                                'Initial Price':initial_price,
                                'Current Price':current_price,
                                'Investment Cost':investment_cost,
                                'Investment Return':investment_return,
                                'Profit/Loss':profit_loss
                                }
                                , columns=['Company',
                                           'Initial Price',
                                           'Current Price',
                                           'Investment Cost',
                                           'Investment Return',
                                           'Profit/Loss'])
        print('Recommended companies for investment and total return as below:')
        print('Total earning from [{0}] till [{1}] is [${2}]'.format(current_key_stats.strftime('%Y-%m-%d'), datetime.datetime.today().strftime('%Y-%m-%d'), round(df_rcmd['Profit/Loss'].sum(),2)))
        print('Total investment cost so far is [${0}]'.format(round(df_rcmd['Investment Cost'].sum(),2)))
        print('Total investment return so far is [${0}]'.format(round(df_rcmd['Investment Return'].sum(),2)))
        print('Total investment return % gain so far is [{0}%]'.format(100*round(df_rcmd['Profit/Loss'].sum(),2)/round(df_rcmd['Investment Cost'].sum(),2)))
        print()
        df_top10 = df_rcmd.nlargest(10, 'Profit/Loss').reset_index().drop(['index'],axis=1)
        print('Top 10 companies by investment profit:')
        print('Top 10 Total earning from [{0}] till [{1}] is [${2}]'.format(current_key_stats.strftime('%Y-%m-%d'), datetime.datetime.today().strftime('%Y-%m-%d'), round(df_top10['Profit/Loss'].sum(),2)))
        print('Top 10 Total investment cost so far is [${0}]'.format(round(df_top10['Investment Cost'].sum(),2)))
        print('Top 10 Total investment return so far is [${0}]'.format(round(df_top10['Investment Return'].sum(),2)))
        print('Top 10 Total investment return % gain so far is [{0}%]'.format(100*round(df_top10['Profit/Loss'].sum(),2)/round(df_top10['Investment Cost'].sum(),2)))        
        print(df_top10)
    else:
        print('Recommended companies for investment as below:')
        df_rcmd = pd.DataFrame(invest_list, columns=['Company'])   
    
    return df_rcmd

# %% [markdown]
# ### Model Execution with GridSearch for Logistic Regression

# %%
def GridSearch_Logistic_Regression_Run(X_train, y_train, X_test, y_test, X_ver, calc_return=True):
    from sklearn.model_selection import GridSearchCV
    from sklearn.linear_model import LogisticRegression
    model = LogisticRegression()

    # Create regularization penalty space
    penalty = ['l1', 'l2']

    # Create regularization hyperparameter space
    C = np.logspace(0, 4, 10)

    # Create hyperparameter options
    hyperparameters = dict(C=C, penalty=penalty)

    # Create grid search using 5-fold cross validation
    clf = GridSearchCV(model, hyperparameters, cv=5, verbose=0)

    # Fit grid search
    best_model = clf.fit(X_train, y_train)

    # View best hyperparameters
    print('GridSearch Logistic Regression Best Penalty:', best_model.best_estimator_.get_params()['penalty'])
    print('GridSearch Logistic Regression Best C:', best_model.best_estimator_.get_params()['C'])

    # Logistic Regression Default accuracy 
    print('GridSearch Logistic Regression Default (accuracy) Train Dataset', best_model.score(X_train, y_train))
    print('GridSearch Logistic Regression Default (accuracy) Test Dataset', best_model.score(X_test, y_test))
    print()

    # Logistic Regression Default metric report
    from sklearn import metrics
    y_pred = best_model.predict(X_test)
    print('GridSearch Logistic Regression Default Metric Report:')
    print(metrics.classification_report(y_pred, y_test))

    # Logistic Regression Default Confusion Matrix
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    print('GridSearch Logistic Regression Default Confusion Matrix:')
    mat = confusion_matrix(y_test, y_pred)
    sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
    plt.xlabel('true label')
    plt.ylabel('predicted label')
    plt.show();

    # Calculate AUROC
    from sklearn.metrics import roc_auc_score   
    y_prob = best_model.predict_proba(X_test)
    y_prob = [p[1] for p in y_prob]

    from sklearn.metrics import roc_curve, auc
    fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label=1)
    auc_result = auc(fpr, tpr)
    print('GridSearch Logistic Regression ROC Curve')
    print('AUROC Score:',roc_auc_score(y_test, y_prob))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='area = {0:0.2f}'.format(auc_result))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()

    #test with latest stock key statistic
    import datetime
    print('Predict using latest Key Statistic @ {0}'.format(current_key_stats.strftime('%Y-%m-%d')))   
    y_pred = best_model.predict(X_ver)

    counter=0
    invest_list = []
    initial_price = []
    current_price = []
    investment_cost = []
    investment_return = []
    profit_loss = []
    for t in y_pred:   
         if t == 1:                
            invest_list.append(z.iloc[counter]['Security'])            
            if calc_return == True:        
                ini_price = load_quote(z.iloc[counter]['Ticker'],current_key_stats,current_key_stats,search_method='F')        
                cur_price = load_quote(z.iloc[counter]['Ticker'],datetime.date.today()-timedelta(days=1),datetime.date.today()-timedelta(days=1),search_method='B')  
                if ini_price != None:
                    ini_price = round(float(ini_price),2)
                    inv_cost = round(float(ini_price)*invest_unit_per_stock,2)
                else:
                    inv_cost = None
                if cur_price != None:
                    cur_price = round(float(cur_price),2)
                    inv_return = round(float(cur_price)*invest_unit_per_stock,2)
                else:
                    inv_return = None
                if inv_cost != None and inv_return != None:
                    pl = round(inv_return-inv_cost,2)
                else:
                    pl = None
                
                initial_price.append(ini_price)
                current_price.append(cur_price)
                investment_cost.append(inv_cost)
                investment_return.append(inv_return)
                profit_loss.append(pl)
         counter+=1
    
    print()
    if calc_return == True:
        df_rcmd = pd.DataFrame({
                                'Company':invest_list,
                                'Initial Price':initial_price,
                                'Current Price':current_price,
                                'Investment Cost':investment_cost,
                                'Investment Return':investment_return,
                                'Profit/Loss':profit_loss
                                }
                                , columns=['Company',
                                           'Initial Price',
                                           'Current Price',
                                           'Investment Cost',
                                           'Investment Return',
                                           'Profit/Loss'])
        print('Recommended companies for investment and total return as below:')
        print('Total earning from [{0}] till [{1}] is [${2}]'.format(current_key_stats.strftime('%Y-%m-%d'), datetime.datetime.today().strftime('%Y-%m-%d'), round(df_rcmd['Profit/Loss'].sum(),2)))
        print('Total investment cost so far is [${0}]'.format(round(df_rcmd['Investment Cost'].sum(),2)))
        print('Total investment return so far is [${0}]'.format(round(df_rcmd['Investment Return'].sum(),2)))
        print('Total investment return % gain so far is [{0}%]'.format(100*round(df_rcmd['Profit/Loss'].sum(),2)/round(df_rcmd['Investment Cost'].sum(),2)))
        print()
        df_top10 = df_rcmd.nlargest(10, 'Profit/Loss').reset_index().drop(['index'],axis=1)
        print('Top 10 companies by investment profit:')
        print('Top 10 Total earning from [{0}] till [{1}] is [${2}]'.format(current_key_stats.strftime('%Y-%m-%d'), datetime.datetime.today().strftime('%Y-%m-%d'), round(df_top10['Profit/Loss'].sum(),2)))
        print('Top 10 Total investment cost so far is [${0}]'.format(round(df_top10['Investment Cost'].sum(),2)))
        print('Top 10 Total investment return so far is [${0}]'.format(round(df_top10['Investment Return'].sum(),2)))
        print('Top 10 Total investment return % gain so far is [{0}%]'.format(100*round(df_top10['Profit/Loss'].sum(),2)/round(df_top10['Investment Cost'].sum(),2)))        
        print(df_top10)
    else:
        print('Recommended companies for investment as below:')
        df_rcmd = pd.DataFrame(invest_list, columns=['Company'])   
    
    return df_rcmd

# %% [markdown]
# ### Data preparation, preprocessing

# %%
#load historical & current Key Financial Statistic data
df_historical = Load_Historical_Data()
df_forward = Load_Forward_Data()

#check if there's any NaN data in historical & current data
historical_null_val = Check_Null_Data(df_historical)
print('Null value in columns for Historical Data:')
print(historical_null_val)
print()
print('Null value in columns for Forward Data:')
forward_null_val = Check_Null_Data(df_forward)
print(forward_null_val)
print()
# Out:
# Null value in columns for Historical Data:
# Ranking                              0
# Date                                 0
# Unix_Time                            0
# Ticker                               0
# Security                             0
# GICS Sector                          0
# GICS Sub Industry                    0
# Stock Price                        145
# Stock Price Change                   0
# S&P 500 Index                        0
# S&P 500 Index Change                 0
# Stock Price vs S&P 500 Index         0
# Market Cap                          12
# Enterprise Value                    38
# Trailing P/E                       346
# Forward P/E                         84
# PEG Ratio                          162
# Price/Sales                         14
# Price/Book                          69
# Enterprise Value/Revenue            39
# Enterprise Value/EBITDA            440
# Profit Margin                        3
# Operating Margin                    68
# Return on Assets                    87
# Return on Equity                    78
# Revenue                              2
# Revenue Per Share                    1
# Gross Profit                        96
# EBITDA                             367
# Net Income Avl to Common             0
# Diluted EPS                         19
# Total Cash                          30
# Total Cash Per Share                17
# Total Debt                          16
# Total Debt/Equity                  777
# Current Ratio                      489
# Book Value Per Share                 0
# Operating Cash Flow                283
# Levered Free Cash Flow             545
# Beta                               202
# % Held by Insiders                  37
# % Held by Institutions              29
# Shares Short                         0
# Short Ratio                          3
# Short % of Float                   227
# Shares Short.1                       0
# Trailing Annual Dividend Rate     1473
# Trailing Annual Dividend Yield    1063
# dtype: int64
#
# Null value in columns for Forward Data:
# Ranking                           365
# Date                              365
# Unix_Time                         365
# Ticker                              0
# Security                            0
# GICS Sector                         0
# GICS Sub Industry                   0
# Stock Price                       365
# Stock Price Change                365
# S&P 500 Index                     365
# S&P 500 Index Change              365
# Stock Price vs S&P 500 Index      365
# Market Cap                          0
# Enterprise Value                    0
# Trailing P/E                       38
# Forward P/E                         1
# PEG Ratio                           0
# Price/Sales                         0
# Price/Book                         12
# Enterprise Value/Revenue            0
# Enterprise Value/EBITDA             5
# Profit Margin                       0
# Operating Margin                    0
# Return on Assets                    8
# Return on Equity                    8
# Revenue                             0
# Revenue Per Share                   0
# Gross Profit                        2
# EBITDA                              5
# Net Income Avl to Common            0
# Diluted EPS                         0
# Total Cash                          1
# Total Cash Per Share                1
# Total Debt                          7
# Total Debt/Equity                  17
# Current Ratio                       9
# Book Value Per Share                0
# Operating Cash Flow                23
# Levered Free Cash Flow             30
# Beta                                1
# % Held by Insiders                  2
# % Held by Institutions              2
# Shares Short                       30
# Short Ratio                        15
# Short % of Float                    0
# Shares Short.1                     30
# Trailing Annual Dividend Rate      47
# Trailing Annual Dividend Yield     31
# dtype: int64

# %% [markdown]
# ### Stock Analysis using Logistic Regression + Standard Scale + Down-Sampling Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_std_scale, X_test_std_scale, X_ver_std_scale = Standard_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_std_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
X_train_std_scale_reduce, y_train_reduce = Down_Sample_Dataset(X_train_std_scale, y_train)

#model execution with Logistic Regression
df_result = Logistic_Regression_Run(X_train_std_scale_reduce, y_train_reduce, X_test_std_scale, y_test, X_ver_std_scale, calc_return=True)
df_result.to_csv('Logistic_Regression_Std_Scale_Down_Sampling.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# Y before down-sampling: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y after down-sampling: (array([0, 1], dtype=int64), array([461, 461], dtype=int64))
# Logistic Regression Default (accuracy) Train Dataset 0.636659436009
# Logistic Regression Default (accuracy) Test Dataset 0.536714610144
#
# Logistic Regression Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.53      0.91      0.67       672
#           1       0.62      0.15      0.24       649
#
# avg / total       0.57      0.54      0.46      1321
#
# Logistic Regression Default Confusion Matrix:
# ROC Curve
# AUROC Score: 0.601753997676
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$603.97]
# Total investment cost so far is [$14434.34]
# Total investment return so far is [$15038.31]
# Total investment return % gain so far is [4.184257818507809%]
#
# Top 10 companies by investment profit:
# Top 10 Total earning from [2018-02-05] till [2018-03-15] is [$299.8]
# Top 10 Total investment cost so far is [$2122.8]
# Top 10 Total investment return so far is [$2422.6]
# Top 10 Total investment return % gain so far is [14.122856604484642%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6        Sherwin-Williams         392.38         413.77           392.38
# 7             Intuit Inc.         157.65         177.68           157.65
# 8        KLA-Tencor Corp.         100.63         120.48           100.63
# 9      Cintas Corporation         156.46         176.13           156.46
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             413.77        21.39
# 7             177.68        20.03
# 8             120.48        19.85
# 9             176.13        19.67
#                                Company  Initial Price  Current Price  \
# 0                        Accenture plc         151.83         162.49
# 1                  Activision Blizzard          67.98          75.93
# 2                    Adobe Systems Inc         190.27         219.76
# 3           Advanced Micro Devices Inc          11.57          11.64
# 4         Air Products & Chemicals Inc         156.33         170.93
# 5              Akamai Technologies Inc          62.81          73.30
# 6                American Tower Corp A         142.04         146.25
# 7               AmerisourceBergen Corp          91.54         100.60
# 8                        Amphenol Corp          88.41          92.51
# 9                 Analog Devices, Inc.          84.96          94.66
# 10                             Aon plc         140.34         145.96
# 11           Automatic Data Processing         113.45         117.39
# 12                 Avery Dennison Corp         113.36         115.91
# 13           Baxter International Inc.          65.37          68.09
# 14                   Best Buy Co. Inc.          68.02          71.52
# 15                         Biogen Inc.         328.31         283.24
# 16                      Boeing Company         327.26         338.67
# 17                          BorgWarner          52.17          50.83
# 18                   Boston Scientific          26.40          28.43
# 19            C. H. Robinson Worldwide          89.88          91.71
# 20                            CA, Inc.          33.32          36.27
# 21                     Cabot Oil & Gas          24.08          25.64
# 22                       Campbell Soup          44.22          43.94
# 23                Cardinal Health Inc.          64.34          72.27
# 24                          Carmax Inc          64.82          62.62
# 25                              Cerner          63.41          63.05
# 26                         CIGNA Corp.         196.36         164.39
# 27                  Cintas Corporation         156.46         176.13
# 28                  The Clorox Company         127.00         131.19
# 29                          CMS Energy          42.37          42.96
# ..                                 ...            ...            ...
# 104                  Quest Diagnostics         100.10         104.99
# 105                       Red Hat Inc.         127.05         153.95
# 106              Republic Services Inc          64.94          69.00
# 107          Robert Half International          54.15          59.13
# 108           Rockwell Automation Inc.         183.74         185.42
# 109                   Rockwell Collins         133.92         136.04
# 110                 Roper Technologies         266.75         281.66
# 111                        Ross Stores          76.90          77.00
# 112  Scripps Networks Interactive Inc.          86.39          90.04
# 113                         Sealed Air          44.30          44.74
# 114                   Sherwin-Williams         392.38         413.77
# 115           Simon Property Group Inc         153.19         157.47
# 116             Stanley Black & Decker         157.51         156.63
# 117                        Sysco Corp.          57.48          60.70
# 118                       Textron Inc.          56.62          58.90
# 119                      Tiffany & Co.         100.74         101.29
# 120              Total System Services          84.24          89.51
# 121                        TripAdvisor          35.62          42.28
# 122                         V.F. Corp.          78.14          73.47
# 123             Varian Medical Systems         119.62         125.49
# 124               Vornado Realty Trust          67.58          68.22
# 125                   Vulcan Materials         124.91         121.67
# 126              Waste Management Inc.          81.30          86.66
# 127                 Waters Corporation         203.26         212.13
# 128                 Weyerhaeuser Corp.          34.47          35.55
# 129                    Whirlpool Corp.         170.72         162.72
# 130                      Williams Cos.          29.11          28.02
# 131                  Wyndham Worldwide         116.12         117.74
# 132                         Xilinx Inc          66.62          76.14
# 133                         Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0             151.83             162.49        10.66
# 1              67.98              75.93         7.95
# 2             190.27             219.76        29.49
# 3              11.57              11.64         0.07
# 4             156.33             170.93        14.60
# 5              62.81              73.30        10.49
# 6             142.04             146.25         4.21
# 7              91.54             100.60         9.06
# 8              88.41              92.51         4.10
# 9              84.96              94.66         9.70
# 10            140.34             145.96         5.62
# 11            113.45             117.39         3.94
# 12            113.36             115.91         2.55
# 13             65.37              68.09         2.72
# 14             68.02              71.52         3.50
# 15            328.31             283.24       -45.07
# 16            327.26             338.67        11.41
# 17             52.17              50.83        -1.34
# 18             26.40              28.43         2.03
# 19             89.88              91.71         1.83
# 20             33.32              36.27         2.95
# 21             24.08              25.64         1.56
# 22             44.22              43.94        -0.28
# 23             64.34              72.27         7.93
# 24             64.82              62.62        -2.20
# 25             63.41              63.05        -0.36
# 26            196.36             164.39       -31.97
# 27            156.46             176.13        19.67
# 28            127.00             131.19         4.19
# 29             42.37              42.96         0.59
# ..               ...                ...          ...
# 104           100.10             104.99         4.89
# 105           127.05             153.95        26.90
# 106            64.94              69.00         4.06
# 107            54.15              59.13         4.98
# 108           183.74             185.42         1.68
# 109           133.92             136.04         2.12
# 110           266.75             281.66        14.91
# 111            76.90              77.00         0.10
# 112            86.39              90.04         3.65
# 113            44.30              44.74         0.44
# 114           392.38             413.77        21.39
# 115           153.19             157.47         4.28
# 116           157.51             156.63        -0.88
# 117            57.48              60.70         3.22
# 118            56.62              58.90         2.28
# 119           100.74             101.29         0.55
# 120            84.24              89.51         5.27
# 121            35.62              42.28         6.66
# 122            78.14              73.47        -4.67
# 123           119.62             125.49         5.87
# 124            67.58              68.22         0.64
# 125           124.91             121.67        -3.24
# 126            81.30              86.66         5.36
# 127           203.26             212.13         8.87
# 128            34.47              35.55         1.08
# 129           170.72             162.72        -8.00
# 130            29.11              28.02        -1.09
# 131           116.12             117.74         1.62
# 132            66.62              76.14         9.52
# 133            72.45              77.98         5.53
#
# [134 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using GridSearch + Logistic Regression + Standard Scale + Down-Sampling Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_std_scale, X_test_std_scale, X_ver_std_scale = Standard_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_std_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
X_train_std_scale_reduce, y_train_reduce = Down_Sample_Dataset(X_train_std_scale, y_train)

#model execution with GridSearch Logistic Regression
df_result = GridSearch_Logistic_Regression_Run(X_train_std_scale_reduce, y_train_reduce, X_test_std_scale, y_test, X_ver_std_scale, calc_return=True)
df_result.to_csv('GridSearch_Logistic_Regression_Std_Scale_Down_Sampling.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# Y before down-sampling: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y after down-sampling: (array([0, 1], dtype=int64), array([461, 461], dtype=int64))
# GridSearch Logistic Regression Best Penalty: l1
# GridSearch Logistic Regression Best C: 2.78255940221
# GridSearch Logistic Regression Default (accuracy) Train Dataset 0.638828633406
# GridSearch Logistic Regression Default (accuracy) Test Dataset 0.537471612415
#
# GridSearch Logistic Regression Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.53      0.91      0.67       673
#           1       0.62      0.15      0.24       648
#
# avg / total       0.57      0.54      0.46      1321
#
# GridSearch Logistic Regression Default Confusion Matrix:
# GridSearch Logistic Regression ROC Curve
# AUROC Score: 0.602423504675
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$608.77]
# Total investment cost so far is [$14763.89]
# Total investment return so far is [$15372.66]
# Total investment return % gain so far is [4.123371279520506%]
#
# Top 10 companies by investment profit:
# Top 10 Total earning from [2018-02-05] till [2018-03-15] is [$299.8]
# Top 10 Total investment cost so far is [$2122.8]
# Top 10 Total investment return so far is [$2422.6]
# Top 10 Total investment return % gain so far is [14.122856604484642%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6        Sherwin-Williams         392.38         413.77           392.38
# 7             Intuit Inc.         157.65         177.68           157.65
# 8        KLA-Tencor Corp.         100.63         120.48           100.63
# 9      Cintas Corporation         156.46         176.13           156.46
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             413.77        21.39
# 7             177.68        20.03
# 8             120.48        19.85
# 9             176.13        19.67
#                                Company  Initial Price  Current Price  \
# 0                        Accenture plc         151.83         162.49
# 1                  Activision Blizzard          67.98          75.93
# 2                    Adobe Systems Inc         190.27         219.76
# 3           Advanced Micro Devices Inc          11.57          11.64
# 4         Air Products & Chemicals Inc         156.33         170.93
# 5              Akamai Technologies Inc          62.81          73.30
# 6                        Allstate Corp          94.55          96.41
# 7                American Tower Corp A         142.04         146.25
# 8               AmerisourceBergen Corp          91.54         100.60
# 9                        Amphenol Corp          88.41          92.51
# 10                Analog Devices, Inc.          84.96          94.66
# 11                             Aon plc         140.34         145.96
# 12           Automatic Data Processing         113.45         117.39
# 13         AvalonBay Communities, Inc.         159.02         161.52
# 14                 Avery Dennison Corp         113.36         115.91
# 15           Baxter International Inc.          65.37          68.09
# 16                   Best Buy Co. Inc.          68.02          71.52
# 17                         Biogen Inc.         328.31         283.24
# 18                      Boeing Company         327.26         338.67
# 19                          BorgWarner          52.17          50.83
# 20                   Boston Scientific          26.40          28.43
# 21            C. H. Robinson Worldwide          89.88          91.71
# 22                            CA, Inc.          33.32          36.27
# 23                     Cabot Oil & Gas          24.08          25.64
# 24                       Campbell Soup          44.22          43.94
# 25                Cardinal Health Inc.          64.34          72.27
# 26                          Carmax Inc          64.82          62.62
# 27                              Cerner          63.41          63.05
# 28                         CIGNA Corp.         196.36         164.39
# 29                  Cintas Corporation         156.46         176.13
# ..                                 ...            ...            ...
# 107                  Quest Diagnostics         100.10         104.99
# 108                       Red Hat Inc.         127.05         153.95
# 109              Republic Services Inc          64.94          69.00
# 110          Robert Half International          54.15          59.13
# 111           Rockwell Automation Inc.         183.74         185.42
# 112                   Rockwell Collins         133.92         136.04
# 113                 Roper Technologies         266.75         281.66
# 114                        Ross Stores          76.90          77.00
# 115  Scripps Networks Interactive Inc.          86.39          90.04
# 116                         Sealed Air          44.30          44.74
# 117                   Sherwin-Williams         392.38         413.77
# 118           Simon Property Group Inc         153.19         157.47
# 119             Stanley Black & Decker         157.51         156.63
# 120                        Sysco Corp.          57.48          60.70
# 121                       Textron Inc.          56.62          58.90
# 122                      Tiffany & Co.         100.74         101.29
# 123              Total System Services          84.24          89.51
# 124                        TripAdvisor          35.62          42.28
# 125                         V.F. Corp.          78.14          73.47
# 126             Varian Medical Systems         119.62         125.49
# 127               Vornado Realty Trust          67.58          68.22
# 128                   Vulcan Materials         124.91         121.67
# 129              Waste Management Inc.          81.30          86.66
# 130                 Waters Corporation         203.26         212.13
# 131                 Weyerhaeuser Corp.          34.47          35.55
# 132                    Whirlpool Corp.         170.72         162.72
# 133                      Williams Cos.          29.11          28.02
# 134                  Wyndham Worldwide         116.12         117.74
# 135                         Xilinx Inc          66.62          76.14
# 136                         Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0             151.83             162.49        10.66
# 1              67.98              75.93         7.95
# 2             190.27             219.76        29.49
# 3              11.57              11.64         0.07
# 4             156.33             170.93        14.60
# 5              62.81              73.30        10.49
# 6              94.55              96.41         1.86
# 7             142.04             146.25         4.21
# 8              91.54             100.60         9.06
# 9              88.41              92.51         4.10
# 10             84.96              94.66         9.70
# 11            140.34             145.96         5.62
# 12            113.45             117.39         3.94
# 13            159.02             161.52         2.50
# 14            113.36             115.91         2.55
# 15             65.37              68.09         2.72
# 16             68.02              71.52         3.50
# 17            328.31             283.24       -45.07
# 18            327.26             338.67        11.41
# 19             52.17              50.83        -1.34
# 20             26.40              28.43         2.03
# 21             89.88              91.71         1.83
# 22             33.32              36.27         2.95
# 23             24.08              25.64         1.56
# 24             44.22              43.94        -0.28
# 25             64.34              72.27         7.93
# 26             64.82              62.62        -2.20
# 27             63.41              63.05        -0.36
# 28            196.36             164.39       -31.97
# 29            156.46             176.13        19.67
# ..               ...                ...          ...
# 107           100.10             104.99         4.89
# 108           127.05             153.95        26.90
# 109            64.94              69.00         4.06
# 110            54.15              59.13         4.98
# 111           183.74             185.42         1.68
# 112           133.92             136.04         2.12
# 113           266.75             281.66        14.91
# 114            76.90              77.00         0.10
# 115            86.39              90.04         3.65
# 116            44.30              44.74         0.44
# 117           392.38             413.77        21.39
# 118           153.19             157.47         4.28
# 119           157.51             156.63        -0.88
# 120            57.48              60.70         3.22
# 121            56.62              58.90         2.28
# 122           100.74             101.29         0.55
# 123            84.24              89.51         5.27
# 124            35.62              42.28         6.66
# 125            78.14              73.47        -4.67
# 126           119.62             125.49         5.87
# 127            67.58              68.22         0.64
# 128           124.91             121.67        -3.24
# 129            81.30              86.66         5.36
# 130           203.26             212.13         8.87
# 131            34.47              35.55         1.08
# 132           170.72             162.72        -8.00
# 133            29.11              28.02        -1.09
# 134           116.12             117.74         1.62
# 135            66.62              76.14         9.52
# 136            72.45              77.98         5.53
#
# [137 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using Logistic Regression + Standard Scale  + PCA + Down-Sampling Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_std_scale, X_test_std_scale, X_ver_std_scale = Standard_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_std_scale)
X_train_std_scale_PCA, X_test_std_scale_PCA, X_ver_std_scale_PCA = PCA_Component_Selection(20, X_train_std_scale, X_test_std_scale, X_ver_std_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
X_train_std_scale_PCA_reduce, y_train_reduce = Down_Sample_Dataset(X_train_std_scale_PCA, y_train)

#model execution with Logistic Regression
df_result = Logistic_Regression_Run(X_train_std_scale_PCA_reduce, y_train_reduce, X_test_std_scale_PCA, y_test, X_ver_std_scale_PCA, calc_return=True)
df_result.to_csv('Logistic_Regression_Std_Scale_PCA_Down_Sampling.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# Y before down-sampling: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y after down-sampling: (array([0, 1], dtype=int64), array([461, 461], dtype=int64))
# Logistic Regression Default (accuracy) Train Dataset 0.638828633406
# Logistic Regression Default (accuracy) Test Dataset 0.537471612415
#
# Logistic Regression Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.53      0.91      0.67       679
#           1       0.60      0.14      0.23       642
#
# avg / total       0.56      0.54      0.46      1321
#
# Logistic Regression Default Confusion Matrix:
# ROC Curve
# AUROC Score: 0.609422896033
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$676.49]
# Total investment cost so far is [$15783.19]
# Total investment return so far is [$16459.68]
# Total investment return % gain so far is [4.286142408473825%]
#
# Top 10 companies by investment profit:
# Top 10 Total earning from [2018-02-05] till [2018-03-15] is [$299.8]
# Top 10 Total investment cost so far is [$2122.8]
# Top 10 Total investment return so far is [$2422.6]
# Top 10 Total investment return % gain so far is [14.122856604484642%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6        Sherwin-Williams         392.38         413.77           392.38
# 7             Intuit Inc.         157.65         177.68           157.65
# 8        KLA-Tencor Corp.         100.63         120.48           100.63
# 9      Cintas Corporation         156.46         176.13           156.46
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             413.77        21.39
# 7             177.68        20.03
# 8             120.48        19.85
# 9             176.13        19.67
#                                Company  Initial Price  Current Price  \
# 0                        Accenture plc         151.83         162.49
# 1                  Activision Blizzard          67.98          75.93
# 2                    Adobe Systems Inc         190.27         219.76
# 3           Advanced Micro Devices Inc          11.57          11.64
# 4                            Aetna Inc         180.95         177.44
# 5         Air Products & Chemicals Inc         156.33         170.93
# 6              Akamai Technologies Inc          62.81          73.30
# 7              Alexion Pharmaceuticals         112.72         121.08
# 8                        Allstate Corp          94.55          96.41
# 9                American Tower Corp A         142.04         146.25
# 10              AmerisourceBergen Corp          91.54         100.60
# 11                          Amgen Inc.         173.44         189.75
# 12                       Amphenol Corp          88.41          92.51
# 13                Analog Devices, Inc.          84.96          94.66
# 14                             Aon plc         140.34         145.96
# 15                       Assurant Inc.          87.62          89.10
# 16           Automatic Data Processing         113.45         117.39
# 17         AvalonBay Communities, Inc.         159.02         161.52
# 18                 Avery Dennison Corp         113.36         115.91
# 19                           Ball Corp          36.42          41.62
# 20           Baxter International Inc.          65.37          68.09
# 21                   Best Buy Co. Inc.          68.02          71.52
# 22                         Biogen Inc.         328.31         283.24
# 23                      Boeing Company         327.26         338.67
# 24                          BorgWarner          52.17          50.83
# 25                   Boston Scientific          26.40          28.43
# 26            C. H. Robinson Worldwide          89.88          91.71
# 27                            CA, Inc.          33.32          36.27
# 28                     Cabot Oil & Gas          24.08          25.64
# 29                       Campbell Soup          44.22          43.94
# ..                                 ...            ...            ...
# 117          Robert Half International          54.15          59.13
# 118           Rockwell Automation Inc.         183.74         185.42
# 119                   Rockwell Collins         133.92         136.04
# 120                 Roper Technologies         266.75         281.66
# 121                        Ross Stores          76.90          77.00
# 122  Scripps Networks Interactive Inc.          86.39          90.04
# 123                         Sealed Air          44.30          44.74
# 124                   Sherwin-Williams         392.38         413.77
# 125           Simon Property Group Inc         153.19         157.47
# 126             Stanley Black & Decker         157.51         156.63
# 127                        Sysco Corp.          57.48          60.70
# 128               TE Connectivity Ltd.          98.33         104.62
# 129                         TechnipFMC          31.83          30.34
# 130                  Texas Instruments         104.21         110.59
# 131                       Textron Inc.          56.62          58.90
# 132                      Tiffany & Co.         100.74         101.29
# 133              Total System Services          84.24          89.51
# 134                        TripAdvisor          35.62          42.28
# 135                         V.F. Corp.          78.14          73.47
# 136             Varian Medical Systems         119.62         125.49
# 137               Vornado Realty Trust          67.58          68.22
# 138                   Vulcan Materials         124.91         121.67
# 139              Waste Management Inc.          81.30          86.66
# 140                 Waters Corporation         203.26         212.13
# 141                 Weyerhaeuser Corp.          34.47          35.55
# 142                    Whirlpool Corp.         170.72         162.72
# 143                      Williams Cos.          29.11          28.02
# 144                  Wyndham Worldwide         116.12         117.74
# 145                         Xilinx Inc          66.62          76.14
# 146                         Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0             151.83             162.49        10.66
# 1              67.98              75.93         7.95
# 2             190.27             219.76        29.49
# 3              11.57              11.64         0.07
# 4             180.95             177.44        -3.51
# 5             156.33             170.93        14.60
# 6              62.81              73.30        10.49
# 7             112.72             121.08         8.36
# 8              94.55              96.41         1.86
# 9             142.04             146.25         4.21
# 10             91.54             100.60         9.06
# 11            173.44             189.75        16.31
# 12             88.41              92.51         4.10
# 13             84.96              94.66         9.70
# 14            140.34             145.96         5.62
# 15             87.62              89.10         1.48
# 16            113.45             117.39         3.94
# 17            159.02             161.52         2.50
# 18            113.36             115.91         2.55
# 19             36.42              41.62         5.20
# 20             65.37              68.09         2.72
# 21             68.02              71.52         3.50
# 22            328.31             283.24       -45.07
# 23            327.26             338.67        11.41
# 24             52.17              50.83        -1.34
# 25             26.40              28.43         2.03
# 26             89.88              91.71         1.83
# 27             33.32              36.27         2.95
# 28             24.08              25.64         1.56
# 29             44.22              43.94        -0.28
# ..               ...                ...          ...
# 117            54.15              59.13         4.98
# 118           183.74             185.42         1.68
# 119           133.92             136.04         2.12
# 120           266.75             281.66        14.91
# 121            76.90              77.00         0.10
# 122            86.39              90.04         3.65
# 123            44.30              44.74         0.44
# 124           392.38             413.77        21.39
# 125           153.19             157.47         4.28
# 126           157.51             156.63        -0.88
# 127            57.48              60.70         3.22
# 128            98.33             104.62         6.29
# 129            31.83              30.34        -1.49
# 130           104.21             110.59         6.38
# 131            56.62              58.90         2.28
# 132           100.74             101.29         0.55
# 133            84.24              89.51         5.27
# 134            35.62              42.28         6.66
# 135            78.14              73.47        -4.67
# 136           119.62             125.49         5.87
# 137            67.58              68.22         0.64
# 138           124.91             121.67        -3.24
# 139            81.30              86.66         5.36
# 140           203.26             212.13         8.87
# 141            34.47              35.55         1.08
# 142           170.72             162.72        -8.00
# 143            29.11              28.02        -1.09
# 144           116.12             117.74         1.62
# 145            66.62              76.14         9.52
# 146            72.45              77.98         5.53
#
# [147 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using GridSearch + Logistic Regression + Standard Scale + PCA + Down-Sampling Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_std_scale, X_test_std_scale, X_ver_std_scale = Standard_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_std_scale)
X_train_std_scale_PCA, X_test_std_scale_PCA, X_ver_std_scale_PCA = PCA_Component_Selection(20, X_train_std_scale, X_test_std_scale, X_ver_std_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
X_train_std_scale_PCA_reduce, y_train_reduce = Down_Sample_Dataset(X_train_std_scale_PCA, y_train)

#model execution with GridSearch Logistic Regression
df_result = GridSearch_Logistic_Regression_Run(X_train_std_scale_PCA_reduce, y_train_reduce, X_test_std_scale_PCA, y_test, X_ver_std_scale_PCA, calc_return=True)
df_result.to_csv('GridSearch_Logistic_Regression_Std_Scale_PCA_Down_Sampling.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# Y before down-sampling: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y after down-sampling: (array([0, 1], dtype=int64), array([461, 461], dtype=int64))
# GridSearch Logistic Regression Best Penalty: l2
# GridSearch Logistic Regression Best C: 1.0
# GridSearch Logistic Regression Default (accuracy) Train Dataset 0.638828633406
# GridSearch Logistic Regression Default (accuracy) Test Dataset 0.537471612415
#
# GridSearch Logistic Regression Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.53      0.91      0.67       679
#           1       0.60      0.14      0.23       642
#
# avg / total       0.56      0.54      0.46      1321
#
# GridSearch Logistic Regression Default Confusion Matrix:
# GridSearch Logistic Regression ROC Curve
# AUROC Score: 0.609422896033
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$676.49]
# Total investment cost so far is [$15783.19]
# Total investment return so far is [$16459.68]
# Total investment return % gain so far is [4.286142408473825%]
#
# Top 10 companies by investment profit:
# Top 10 Total earning from [2018-02-05] till [2018-03-15] is [$299.8]
# Top 10 Total investment cost so far is [$2122.8]
# Top 10 Total investment return so far is [$2422.6]
# Top 10 Total investment return % gain so far is [14.122856604484642%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6        Sherwin-Williams         392.38         413.77           392.38
# 7             Intuit Inc.         157.65         177.68           157.65
# 8        KLA-Tencor Corp.         100.63         120.48           100.63
# 9      Cintas Corporation         156.46         176.13           156.46
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             413.77        21.39
# 7             177.68        20.03
# 8             120.48        19.85
# 9             176.13        19.67
#                                Company  Initial Price  Current Price  \
# 0                        Accenture plc         151.83         162.49
# 1                  Activision Blizzard          67.98          75.93
# 2                    Adobe Systems Inc         190.27         219.76
# 3           Advanced Micro Devices Inc          11.57          11.64
# 4                            Aetna Inc         180.95         177.44
# 5         Air Products & Chemicals Inc         156.33         170.93
# 6              Akamai Technologies Inc          62.81          73.30
# 7              Alexion Pharmaceuticals         112.72         121.08
# 8                        Allstate Corp          94.55          96.41
# 9                American Tower Corp A         142.04         146.25
# 10              AmerisourceBergen Corp          91.54         100.60
# 11                          Amgen Inc.         173.44         189.75
# 12                       Amphenol Corp          88.41          92.51
# 13                Analog Devices, Inc.          84.96          94.66
# 14                             Aon plc         140.34         145.96
# 15                       Assurant Inc.          87.62          89.10
# 16           Automatic Data Processing         113.45         117.39
# 17         AvalonBay Communities, Inc.         159.02         161.52
# 18                 Avery Dennison Corp         113.36         115.91
# 19                           Ball Corp          36.42          41.62
# 20           Baxter International Inc.          65.37          68.09
# 21                   Best Buy Co. Inc.          68.02          71.52
# 22                         Biogen Inc.         328.31         283.24
# 23                      Boeing Company         327.26         338.67
# 24                          BorgWarner          52.17          50.83
# 25                   Boston Scientific          26.40          28.43
# 26            C. H. Robinson Worldwide          89.88          91.71
# 27                            CA, Inc.          33.32          36.27
# 28                     Cabot Oil & Gas          24.08          25.64
# 29                       Campbell Soup          44.22          43.94
# ..                                 ...            ...            ...
# 117          Robert Half International          54.15          59.13
# 118           Rockwell Automation Inc.         183.74         185.42
# 119                   Rockwell Collins         133.92         136.04
# 120                 Roper Technologies         266.75         281.66
# 121                        Ross Stores          76.90          77.00
# 122  Scripps Networks Interactive Inc.          86.39          90.04
# 123                         Sealed Air          44.30          44.74
# 124                   Sherwin-Williams         392.38         413.77
# 125           Simon Property Group Inc         153.19         157.47
# 126             Stanley Black & Decker         157.51         156.63
# 127                        Sysco Corp.          57.48          60.70
# 128               TE Connectivity Ltd.          98.33         104.62
# 129                         TechnipFMC          31.83          30.34
# 130                  Texas Instruments         104.21         110.59
# 131                       Textron Inc.          56.62          58.90
# 132                      Tiffany & Co.         100.74         101.29
# 133              Total System Services          84.24          89.51
# 134                        TripAdvisor          35.62          42.28
# 135                         V.F. Corp.          78.14          73.47
# 136             Varian Medical Systems         119.62         125.49
# 137               Vornado Realty Trust          67.58          68.22
# 138                   Vulcan Materials         124.91         121.67
# 139              Waste Management Inc.          81.30          86.66
# 140                 Waters Corporation         203.26         212.13
# 141                 Weyerhaeuser Corp.          34.47          35.55
# 142                    Whirlpool Corp.         170.72         162.72
# 143                      Williams Cos.          29.11          28.02
# 144                  Wyndham Worldwide         116.12         117.74
# 145                         Xilinx Inc          66.62          76.14
# 146                         Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0             151.83             162.49        10.66
# 1              67.98              75.93         7.95
# 2             190.27             219.76        29.49
# 3              11.57              11.64         0.07
# 4             180.95             177.44        -3.51
# 5             156.33             170.93        14.60
# 6              62.81              73.30        10.49
# 7             112.72             121.08         8.36
# 8              94.55              96.41         1.86
# 9             142.04             146.25         4.21
# 10             91.54             100.60         9.06
# 11            173.44             189.75        16.31
# 12             88.41              92.51         4.10
# 13             84.96              94.66         9.70
# 14            140.34             145.96         5.62
# 15             87.62              89.10         1.48
# 16            113.45             117.39         3.94
# 17            159.02             161.52         2.50
# 18            113.36             115.91         2.55
# 19             36.42              41.62         5.20
# 20             65.37              68.09         2.72
# 21             68.02              71.52         3.50
# 22            328.31             283.24       -45.07
# 23            327.26             338.67        11.41
# 24             52.17              50.83        -1.34
# 25             26.40              28.43         2.03
# 26             89.88              91.71         1.83
# 27             33.32              36.27         2.95
# 28             24.08              25.64         1.56
# 29             44.22              43.94        -0.28
# ..               ...                ...          ...
# 117            54.15              59.13         4.98
# 118           183.74             185.42         1.68
# 119           133.92             136.04         2.12
# 120           266.75             281.66        14.91
# 121            76.90              77.00         0.10
# 122            86.39              90.04         3.65
# 123            44.30              44.74         0.44
# 124           392.38             413.77        21.39
# 125           153.19             157.47         4.28
# 126           157.51             156.63        -0.88
# 127            57.48              60.70         3.22
# 128            98.33             104.62         6.29
# 129            31.83              30.34        -1.49
# 130           104.21             110.59         6.38
# 131            56.62              58.90         2.28
# 132           100.74             101.29         0.55
# 133            84.24              89.51         5.27
# 134            35.62              42.28         6.66
# 135            78.14              73.47        -4.67
# 136           119.62             125.49         5.87
# 137            67.58              68.22         0.64
# 138           124.91             121.67        -3.24
# 139            81.30              86.66         5.36
# 140           203.26             212.13         8.87
# 141            34.47              35.55         1.08
# 142           170.72             162.72        -8.00
# 143            29.11              28.02        -1.09
# 144           116.12             117.74         1.62
# 145            66.62              76.14         9.52
# 146            72.45              77.98         5.53
#
# [147 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using Logistic Regression + MinMax Scale + Down-Sampling Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_mm_scale, X_test_mm_scale, X_ver_mm_scale = MinMax_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_mm_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
X_train_mm_scale_reduce, y_train_reduce = Down_Sample_Dataset(X_train_mm_scale, y_train)

#model execution with Logistic Regression
df_result = Logistic_Regression_Run(X_train_mm_scale_reduce, y_train_reduce, X_test_mm_scale, y_test, X_ver_mm_scale, calc_return=True)
df_result.to_csv('Logistic_Regression_mm_Scale_Down_Sampling.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# Y before down-sampling: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y after down-sampling: (array([0, 1], dtype=int64), array([461, 461], dtype=int64))
# Logistic Regression Default (accuracy) Train Dataset 0.631236442516
# Logistic Regression Default (accuracy) Test Dataset 0.467070401211
#
# Logistic Regression Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.44      0.92      0.59       554
#           1       0.70      0.14      0.24       767
#
# avg / total       0.59      0.47      0.39      1321
#
# Logistic Regression Default Confusion Matrix:
# ROC Curve
# AUROC Score: 0.616903668456
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$664.22]
# Total investment cost so far is [$17275.3]
# Total investment return so far is [$17939.52]
# Total investment return % gain so far is [3.84491152107344%]
#
# Top 10 companies by investment profit:
# Top 10 Total earning from [2018-02-05] till [2018-03-15] is [$301.59]
# Top 10 Total investment cost so far is [$2047.79]
# Top 10 Total investment return so far is [$2349.38]
# Top 10 Total investment return % gain so far is [14.727584371444337%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6         Western Digital          81.45         102.91            81.45
# 7        Sherwin-Williams         392.38         413.77           392.38
# 8             Intuit Inc.         157.65         177.68           157.65
# 9        KLA-Tencor Corp.         100.63         120.48           100.63
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             102.91        21.46
# 7             413.77        21.39
# 8             177.68        20.03
# 9             120.48        19.85
#                                Company  Initial Price  Current Price  \
# 0                  Activision Blizzard          67.98          75.93
# 1                    Adobe Systems Inc         190.27         219.76
# 2                            Aetna Inc         180.95         177.44
# 3                            AFLAC Inc          85.71          90.75
# 4         Air Products & Chemicals Inc         156.33         170.93
# 5              Akamai Technologies Inc          62.81          73.30
# 6              Alexion Pharmaceuticals         112.72         121.08
# 7                        Allstate Corp          94.55          96.41
# 8                          Ameren Corp          53.69          54.09
# 9                American Tower Corp A         142.04         146.25
# 10              AmerisourceBergen Corp          91.54         100.60
# 11                       Amphenol Corp          88.41          92.51
# 12                Analog Devices, Inc.          84.96          94.66
# 13                             Aon plc         140.34         145.96
# 14                  Apache Corporation          40.93          35.46
# 15           Archer-Daniels-Midland Co          40.29          44.24
# 16                       Assurant Inc.          87.62          89.10
# 17           Automatic Data Processing         113.45         117.39
# 18         AvalonBay Communities, Inc.         159.02         161.52
# 19                 Avery Dennison Corp         113.36         115.91
# 20                           Ball Corp          36.42          41.62
# 21           Baxter International Inc.          65.37          68.09
# 22                    Becton Dickinson         224.05         223.85
# 23                   Best Buy Co. Inc.          68.02          71.52
# 24                         Biogen Inc.         328.31         283.24
# 25                          BorgWarner          52.17          50.83
# 26                   Boston Scientific          26.40          28.43
# 27            C. H. Robinson Worldwide          89.88          91.71
# 28                            CA, Inc.          33.32          36.27
# 29                     Cabot Oil & Gas          24.08          25.64
# ..                                 ...            ...            ...
# 136                        Ross Stores          76.90          77.00
# 137  Scripps Networks Interactive Inc.          86.39          90.04
# 138                         Sealed Air          44.30          44.74
# 139                   Sherwin-Williams         392.38         413.77
# 140           Simon Property Group Inc         153.19         157.47
# 141             Stanley Black & Decker         157.51         156.63
# 142                        Sysco Corp.          57.48          60.70
# 143               TE Connectivity Ltd.          98.33         104.62
# 144                       Textron Inc.          56.62          58.90
# 145           Thermo Fisher Scientific         208.15         214.95
# 146                      Tiffany & Co.         100.74         101.29
# 147              Total System Services          84.24          89.51
# 148       The Travelers Companies Inc.         140.79         140.69
# 149                        TripAdvisor          35.62          42.28
# 150                         Unum Group          50.43          50.32
# 151                         V.F. Corp.          78.14          73.47
# 152             Varian Medical Systems         119.62         125.49
# 153                         Ventas Inc          52.88          50.35
# 154               Vornado Realty Trust          67.58          68.22
# 155                   Vulcan Materials         124.91         121.67
# 156              Waste Management Inc.          81.30          86.66
# 157                 Waters Corporation         203.26         212.13
# 158                    Western Digital          81.45         102.91
# 159                 Weyerhaeuser Corp.          34.47          35.55
# 160                    Whirlpool Corp.         170.72         162.72
# 161                      Williams Cos.          29.11          28.02
# 162                  Wyndham Worldwide         116.12         117.74
# 163                        Xerox Corp.          31.38          31.34
# 164                         Xilinx Inc          66.62          76.14
# 165                         Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0              67.98              75.93         7.95
# 1             190.27             219.76        29.49
# 2             180.95             177.44        -3.51
# 3              85.71              90.75         5.04
# 4             156.33             170.93        14.60
# 5              62.81              73.30        10.49
# 6             112.72             121.08         8.36
# 7              94.55              96.41         1.86
# 8              53.69              54.09         0.40
# 9             142.04             146.25         4.21
# 10             91.54             100.60         9.06
# 11             88.41              92.51         4.10
# 12             84.96              94.66         9.70
# 13            140.34             145.96         5.62
# 14             40.93              35.46        -5.47
# 15             40.29              44.24         3.95
# 16             87.62              89.10         1.48
# 17            113.45             117.39         3.94
# 18            159.02             161.52         2.50
# 19            113.36             115.91         2.55
# 20             36.42              41.62         5.20
# 21             65.37              68.09         2.72
# 22            224.05             223.85        -0.20
# 23             68.02              71.52         3.50
# 24            328.31             283.24       -45.07
# 25             52.17              50.83        -1.34
# 26             26.40              28.43         2.03
# 27             89.88              91.71         1.83
# 28             33.32              36.27         2.95
# 29             24.08              25.64         1.56
# ..               ...                ...          ...
# 136            76.90              77.00         0.10
# 137            86.39              90.04         3.65
# 138            44.30              44.74         0.44
# 139           392.38             413.77        21.39
# 140           153.19             157.47         4.28
# 141           157.51             156.63        -0.88
# 142            57.48              60.70         3.22
# 143            98.33             104.62         6.29
# 144            56.62              58.90         2.28
# 145           208.15             214.95         6.80
# 146           100.74             101.29         0.55
# 147            84.24              89.51         5.27
# 148           140.79             140.69        -0.10
# 149            35.62              42.28         6.66
# 150            50.43              50.32        -0.11
# 151            78.14              73.47        -4.67
# 152           119.62             125.49         5.87
# 153            52.88              50.35        -2.53
# 154            67.58              68.22         0.64
# 155           124.91             121.67        -3.24
# 156            81.30              86.66         5.36
# 157           203.26             212.13         8.87
# 158            81.45             102.91        21.46
# 159            34.47              35.55         1.08
# 160           170.72             162.72        -8.00
# 161            29.11              28.02        -1.09
# 162           116.12             117.74         1.62
# 163            31.38              31.34        -0.04
# 164            66.62              76.14         9.52
# 165            72.45              77.98         5.53
#
# [166 rows x 6 columns]

# %% [markdown]
# ### Stock Analysis using GridSearch + Logistic Regression + MinMax Scale + PCA + Down-Sampling Data

# %%
#analysis target
how_much_better = 20
invest_unit_per_stock = 1

#Historical & Forward null value handling
#ranking=0 - for comparing stock price changes against S&P 500 price changes
#ranking=1 - for comparing stock price changes against its previous price changes
X,y = Historical_Data_Preprocessing_All_Industry(df_historical, ranking=0)
X_ver,z = Forward_Data_Preprocessing_All_Industry(df_forward)

#split historical data into Train & Test set
X_train, X_test, y_train, y_test = Train_Test_Split(X, y)

#Feature Scaling and Normalization for Train, Test & Verification dataset
X_train_mm_scale, X_test_mm_scale, X_ver_mm_scale = MinMax_Scale(X_train, X_test, X_ver)

#check if there's any need for PCA to reduce number of features
print('Total available features:', len(list(X_train)))
PCA_Component_Analysis(X_train_mm_scale)
X_train_mm_scale_PCA, X_test_mm_scale_PCA, X_ver_mm_scale_PCA = PCA_Component_Selection(20, X_train_mm_scale, X_test_mm_scale, X_ver_mm_scale)

#check if there's imbalance dataset?
print('Y train:',np.unique(y_train,return_counts=True))
print('Y test:',np.unique(y_test,return_counts=True))

#handling imbalance dataset by down-sampling the train set data
X_train_mm_scale_PCA_reduce, y_train_reduce = Down_Sample_Dataset(X_train_mm_scale_PCA, y_train)

#model execution with Logistic Regression
df_result = GridSearch_Logistic_Regression_Run(X_train_mm_scale_PCA_reduce, y_train_reduce, X_test_mm_scale_PCA, y_test, X_ver_mm_scale_PCA, calc_return=True)
df_result.to_csv('GridSearch_Logistic_Regression_mm_Scale_PCA_Down_Sampling.csv', index=False)
df_result
# Out:
# Total available features: 24
# Y train: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y test: (array([0, 1], dtype=int64), array([1166,  155], dtype=int64))
# Y before down-sampling: (array([0, 1], dtype=int64), array([3501,  461], dtype=int64))
# Y after down-sampling: (array([0, 1], dtype=int64), array([461, 461], dtype=int64))
# GridSearch Logistic Regression Best Penalty: l1
# GridSearch Logistic Regression Best C: 21.5443469003
# GridSearch Logistic Regression Default (accuracy) Train Dataset 0.636659436009
# GridSearch Logistic Regression Default (accuracy) Test Dataset 0.539742619228
#
# GridSearch Logistic Regression Default Metric Report:
#              precision    recall  f1-score   support
#
#           0       0.53      0.91      0.67       676
#           1       0.62      0.15      0.24       645
#
# avg / total       0.57      0.54      0.46      1321
#
# GridSearch Logistic Regression Default Confusion Matrix:
# GridSearch Logistic Regression ROC Curve
# AUROC Score: 0.606451612903
# Predict using latest Key Statistic @ 2018-02-05
#
# Recommended companies for investment and total return as below:
# Total earning from [2018-02-05] till [2018-03-15] is [$634.49]
# Total investment cost so far is [$14884.4]
# Total investment return so far is [$15518.89]
# Total investment return % gain so far is [4.262785197925345%]
#
# Top 10 companies by investment profit:
# Top 10 Total earning from [2018-02-05] till [2018-03-15] is [$299.8]
# Top 10 Total investment cost so far is [$2122.8]
# Top 10 Total investment return so far is [$2422.6]
# Top 10 Total investment return % gain so far is [14.122856604484642%]
#                   Company  Initial Price  Current Price  Investment Cost  \
# 0            Netflix Inc.         254.26         315.88           254.26
# 1            Lam Research         169.92         223.97           169.92
# 2       Adobe Systems Inc         190.27         219.76           190.27
# 3            Red Hat Inc.         127.05         153.95           127.05
# 4    Grainger (W.W.) Inc.         252.85         276.65           252.85
# 5  Northrop Grumman Corp.         321.33         344.33           321.33
# 6        Sherwin-Williams         392.38         413.77           392.38
# 7             Intuit Inc.         157.65         177.68           157.65
# 8        KLA-Tencor Corp.         100.63         120.48           100.63
# 9      Cintas Corporation         156.46         176.13           156.46
#
#    Investment Return  Profit/Loss
# 0             315.88        61.62
# 1             223.97        54.05
# 2             219.76        29.49
# 3             153.95        26.90
# 4             276.65        23.80
# 5             344.33        23.00
# 6             413.77        21.39
# 7             177.68        20.03
# 8             120.48        19.85
# 9             176.13        19.67
#                                Company  Initial Price  Current Price  \
# 0                        Accenture plc         151.83         162.49
# 1                  Activision Blizzard          67.98          75.93
# 2                    Adobe Systems Inc         190.27         219.76
# 3         Air Products & Chemicals Inc         156.33         170.93
# 4              Akamai Technologies Inc          62.81          73.30
# 5                        Allstate Corp          94.55          96.41
# 6                American Tower Corp A         142.04         146.25
# 7               AmerisourceBergen Corp          91.54         100.60
# 8                        Amphenol Corp          88.41          92.51
# 9                 Analog Devices, Inc.          84.96          94.66
# 10                             Aon plc         140.34         145.96
# 11                       Assurant Inc.          87.62          89.10
# 12           Automatic Data Processing         113.45         117.39
# 13                 Avery Dennison Corp         113.36         115.91
# 14                           Ball Corp          36.42          41.62
# 15           Baxter International Inc.          65.37          68.09
# 16                   Best Buy Co. Inc.          68.02          71.52
# 17                         Biogen Inc.         328.31         283.24
# 18                      Boeing Company         327.26         338.67
# 19                          BorgWarner          52.17          50.83
# 20                   Boston Scientific          26.40          28.43
# 21            C. H. Robinson Worldwide          89.88          91.71
# 22                            CA, Inc.          33.32          36.27
# 23                     Cabot Oil & Gas          24.08          25.64
# 24                       Campbell Soup          44.22          43.94
# 25                Cardinal Health Inc.          64.34          72.27
# 26                          Carmax Inc          64.82          62.62
# 27                              Cerner          63.41          63.05
# 28                         CIGNA Corp.         196.36         164.39
# 29                  Cintas Corporation         156.46         176.13
# ..                                 ...            ...            ...
# 107                  Quest Diagnostics         100.10         104.99
# 108                       Red Hat Inc.         127.05         153.95
# 109              Republic Services Inc          64.94          69.00
# 110          Robert Half International          54.15          59.13
# 111           Rockwell Automation Inc.         183.74         185.42
# 112                   Rockwell Collins         133.92         136.04
# 113                 Roper Technologies         266.75         281.66
# 114                        Ross Stores          76.90          77.00
# 115  Scripps Networks Interactive Inc.          86.39          90.04
# 116                         Sealed Air          44.30          44.74
# 117                   Sherwin-Williams         392.38         413.77
# 118           Simon Property Group Inc         153.19         157.47
# 119             Stanley Black & Decker         157.51         156.63
# 120                        Sysco Corp.          57.48          60.70
# 121                       Textron Inc.          56.62          58.90
# 122                      Tiffany & Co.         100.74         101.29
# 123              Total System Services          84.24          89.51
# 124                        TripAdvisor          35.62          42.28
# 125                         V.F. Corp.          78.14          73.47
# 126             Varian Medical Systems         119.62         125.49
# 127               Vornado Realty Trust          67.58          68.22
# 128                   Vulcan Materials         124.91         121.67
# 129              Waste Management Inc.          81.30          86.66
# 130                 Waters Corporation         203.26         212.13
# 131                 Weyerhaeuser Corp.          34.47          35.55
# 132                    Whirlpool Corp.         170.72         162.72
# 133                      Williams Cos.          29.11          28.02
# 134                  Wyndham Worldwide         116.12         117.74
# 135                         Xilinx Inc          66.62          76.14
# 136                         Xylem Inc.          72.45          77.98
#
#      Investment Cost  Investment Return  Profit/Loss
# 0             151.83             162.49        10.66
# 1              67.98              75.93         7.95
# 2             190.27             219.76        29.49
# 3             156.33             170.93        14.60
# 4              62.81              73.30        10.49
# 5              94.55              96.41         1.86
# 6             142.04             146.25         4.21
# 7              91.54             100.60         9.06
# 8              88.41              92.51         4.10
# 9              84.96              94.66         9.70
# 10            140.34             145.96         5.62
# 11             87.62              89.10         1.48
# 12            113.45             117.39         3.94
# 13            113.36             115.91         2.55
# 14             36.42              41.62         5.20
# 15             65.37              68.09         2.72
# 16             68.02              71.52         3.50
# 17            328.31             283.24       -45.07
# 18            327.26             338.67        11.41
# 19             52.17              50.83        -1.34
# 20             26.40              28.43         2.03
# 21             89.88              91.71         1.83
# 22             33.32              36.27         2.95
# 23             24.08              25.64         1.56
# 24             44.22              43.94        -0.28
# 25             64.34              72.27         7.93
# 26             64.82              62.62        -2.20
# 27             63.41              63.05        -0.36
# 28            196.36             164.39       -31.97
# 29            156.46             176.13        19.67
# ..               ...                ...          ...
# 107           100.10             104.99         4.89
# 108           127.05             153.95        26.90
# 109            64.94              69.00         4.06
# 110            54.15              59.13         4.98
# 111           183.74             185.42         1.68
# 112           133.92             136.04         2.12
# 113           266.75             281.66        14.91
# 114            76.90              77.00         0.10
# 115            86.39              90.04         3.65
# 116            44.30              44.74         0.44
# 117           392.38             413.77        21.39
# 118           153.19             157.47         4.28
# 119           157.51             156.63        -0.88
# 120            57.48              60.70         3.22
# 121            56.62              58.90         2.28
# 122           100.74             101.29         0.55
# 123            84.24              89.51         5.27
# 124            35.62              42.28         6.66
# 125            78.14              73.47        -4.67
# 126           119.62             125.49         5.87
# 127            67.58              68.22         0.64
# 128           124.91             121.67        -3.24
# 129            81.30              86.66         5.36
# 130           203.26             212.13         8.87
# 131            34.47              35.55         1.08
# 132           170.72             162.72        -8.00
# 133            29.11              28.02        -1.09
# 134           116.12             117.74         1.62
# 135            66.62              76.14         9.52
# 136            72.45              77.98         5.53
#
# [137 rows x 6 columns]

# %% [markdown]
# ### Conclusion

# %% [markdown]
# With Logistic Regression, the best estimated model is using the combination of:
#
# "Stock Analysis using GridSearch + Logistic Regression + MinMax Scale + PCA + Down-Sampling Data"
#
# with
#
# - GridSearch Logistic Regression Best Penalty: l1
# - GridSearch Logistic Regression Best C: 21.5443469003
# - GridSearch Logistic Regression Default (accuracy) Train Dataset 0.636659436009
# - GridSearch Logistic Regression Default (accuracy) Test Dataset 0.539742619228
#
# - GridSearch Logistic Regression Default Metric Report:
#                      precision    recall  f1-score   support
#
#                   0       0.53      0.91      0.67       676
#                   1       0.62      0.15      0.24       645
#
#         avg / total       0.57      0.54      0.46      1321
#
# - AUROC Score: 0.606451612903
# - Top 10 investments total return % gain from [2018-02-05] till [2018-03-13] is 14.12%
#
# | Company         |
# |---------------  |
# | `Netflix Inc.` |
# | `Lam Research`        |
# | `Adobe Systems Inc`   |
# | `Red Hat Inc.`   |
# | `Grainger (W.W.) Inc.`   |
# | `Northrop Grumman Corp.`   |
# | `Sherwin-Williams`   |
# | `Intuit Inc.`   |
# | `KLA-Tencor Corp.`   |
# | `Cintas Corporation`   |
